# %% [markdown]
# ## Diseño Evolutivo de Redes Neuronales Artificiales
# ## Evolutionary Design of Artificial Neural Networks
# ## DERNA/EDANN
# Some code based on [Time Series Prediction A Naive Exploration](https://www.researchgate.net/profile/Wilson_Tolentino_Da_Silva2/publication/333982520_Time_Series_Prediction_A_Naive_Exploration/links/5d10ec94299bf1547c7afe08/Time-Series-Prediction-A-Naive-Exploration.pdf)
#
# The objective of this program is to optimize the published code (baseline_tolentino_original) using EDANN.<br>
# On the paper, Tolentino achieves a Test loss of 0.10234724577159098<br>
# My reproduction of the program achieves 0.06509439647197723<br>
# The objective of this program is to outperform those numbers.<br>
#
# This is the first try to integrate the Genetic Algorithm and the ANN.
#
# V 1.0 2020-08-11 Reescritura completa de cero de DERNA, ahora usa arreglos de reales, mapeo, alpha blend y mutación por perturbación o random.

# %% [markdown]
# ### Setup

# %% [markdown]
# #### Install packages

# %%
# !pip install -U deap
# Out:
# Collecting deap
#   Downloading https://files.pythonhosted.org/packages/99/d1/803c7a387d8a7e6866160b1541307f88d534da4291572fb32f69d2548afb/deap-1.3.1-cp37-cp37m-manylinux2010_x86_64.whl (157kB)
#      |████████████████████████████████| 163kB 9.3MB/s
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from deap) (1.19.5)
# Installing collected packages: deap
# Successfully installed deap-1.3.1

# %% [markdown]
# #### Import libraries and functions

# %%
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn.preprocessing as skp
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

from deap import base, creator, tools, algorithms

# %% [markdown]
# #### Hyperparameters

# %%
# define hyperparameters
p = {
     "Window": 30,  # this will be optimized by the GA
     "Neurons": 12,  # this will be optimized by the GA
     "test_split" : 0.20,  # 20% for testing
     "val_split" : 0.10,  # 10% for validation
     "activation": "relu",  # for the hidden layer
     # could be relu, sigmoid, softmax, softplus, softsign, tanh, selu,
     # elu, exponential, or linear
     "output_activation": "linear",  # for the output layer
     "loss": "logcosh",  # could be mse, mae, msle, cs, huber, or logcosh
     "optimizer": "nadam",  # could be sgd, rmsprop, adam, adadelta,
     # adagrad, adamax, nadam, or ftrl
     # or a class instance with sub-parameters like
     # tf.keras.optimizers.SGD(
     #    learning_rate=0.3,
     #    momentum=0.2,
     #    nesterov=False),
     "epochs": 100,  # training epochs
     "batch_size": 30,
     "shuffle": True,  # the training data
     "verbose": 0,  # verbose training, 1 is too chatty, 2 may be convenient
     "population" : 75,  # number of individuals in population
     # should be chosen based on the size of the optimization space
     # (better high around sqrt(space size))
     "ngen" : 30,  # number of generations (just high enough)
     # EDANN does no redundant evaluations
     "ngenes" : 2,  # number of genes in a chromosome
     "genes" : ("Window", "Neurons"),
     "min" : (2, 2),  # minimun value of each gene
     "range" : (200, 30),  # range of values of each gene
     "alpha" : 0.2,  # alpha blend oversize (better not too high)
     "sigma": 0.1,  # for gaussian mutation
     "indpb": 0.2,  # for gaussian mutation
     "tournsize" : 3,  # tournament size
     "cxpb" : 0.6,  # crossover probability (better high)
     "mutpb" : 0.2,  # mutation probability (better low)
    }

# %% [markdown]
# #### Read data from repository

# %%
# copy file from repository
path_to_downloaded_file = tf.keras.utils.get_file(
    "baseline_tolentino.csv",
    "https://raw.githubusercontent.com/jmacostap/webstore/master/"+
    "baseline_tolentino.csv",
    cache_dir="/content",
    )
# load data into a Pandas dataframe
df = pd.read_csv(path_to_downloaded_file)
print(len(df), "lines read")
# Out:
# Downloading data from https://raw.githubusercontent.com/jmacostap/webstore/master/baseline_tolentino.csv
# 335872/328946 [==============================] - 0s 0us/step
# 4829 lines read

# %% [markdown]
# #### Add new columns and drop unused

# %%
# drop columns that will not be used
df.drop(["Date", "Open", "High", "Low", "Volume"], axis=1, inplace=True)

# %% [markdown]
# #### Split data into train and test sets

# %%
# Split the data and convert to 2D Numpy Arrays for MinMaxScaler
test_split = int(len(df) * (1.0 - p["test_split"]))
train = df.iloc[:test_split].values.reshape(-1,1)
test = df.iloc[test_split:].values.reshape(-1,1)

# %% [markdown]
# #### Scale data to [0, 1]

# %%
# scale data
scaler = skp.MinMaxScaler(feature_range=(0, 1))
# it should fit using both arrays, not only train
scaler.partial_fit(train)
scaler.partial_fit(test)
train_scaled = scaler.transform(train).flat
test_scaled = scaler.transform(test).flat

# %% [markdown]
# #### Auxiliary functions definition

# %% [markdown]
# ##### Prepare a time series into sliding windows

# %%
def prepare_time_series(time_series, targets, window):
    """Prepare time series and targets for Keras
    # like tf.keras.preprocessing.sequence.TimeseriesGenerator
    # without the batches
    # In the basic case time_series and targets are the same array

    Args:
    time_series: flat array-like: of values of the time series
    targets: flat array-like: of target values
    X[0] = time_series[0:window]
    Y[0] = targets[window]
    and so on
    
    Returns:
    X: 2D ndarray: of dataset_length vectors of window elements
    Y: 1D ndarray: of targets[window:]
    """

    dataset_length = len(time_series) - window
    X = np.empty((dataset_length, window))
    Y = np.empty((dataset_length, 1))
    for i in range(dataset_length):
        X[i, :] = time_series[i:(i + window)]
        Y[i, 0] = targets[i + window]
    return X, Y

# %% [markdown]
# ##### Create train and test an ANN

# %%
def create_ann(p, train_data, targets):
    """Create an ANN with the parameters on p and train it with train_data

    Args:
    p: dict: of hyperparameters
    train_data: flat array-like: of training data
    targets: flat array-like: of targets
    
    Returns:
    ann: keras.model: the trained neural network
    history: keras.history: the training history
    """

    X_train, y_train = prepare_time_series(
        train_data, targets, p["Window"])
    # ensure reproducibility and consistency across fenotypes
    tf.random.set_seed(31415926)

    ann = Sequential([Dense(units=p["Neurons"],
                            input_dim=p["Window"],
                            activation=p["activation"]),
                      Dense(units=1,
                            activation=p["output_activation"])])

    ann.compile(loss=p["loss"], optimizer=p["optimizer"])

    history = ann.fit(x=X_train,
                      y=y_train,
                      epochs=p["epochs"],
                      batch_size=p["batch_size"],
                      verbose=p["verbose"],
                      validation_split=p["val_split"],
                      shuffle=p["shuffle"])
    
    return ann, history

# %% [markdown]
# ##### Graphically display the performance of a trained ANN

# %%
def display_ann(ann, history, window, batch_size, train_data, test_data):
    """Show the ANN performance with graphs

    Args:
    ann: keras.model: the trained neural network
    history: keras.history: the training history
    window: int: the window size used on ann
    batch_size: int: the batch_size used on ann
    train_data: flat array-like: the train data used for ann.
                Needed for the plots
    test_data: flat array-like: data to test the ann

    Returns:
    Nothing
    """

    import matplotlib.pyplot as plt

    X_train, y_train = prepare_time_series(
        train_data, train_data, window)
    X_test, y_test = prepare_time_series(
        test_data, test_data, window)

    ann_train_loss = ann.evaluate(x=X_train,
        y=y_train,
        batch_size=batch_size)
    ann_test_loss = ann.evaluate(x=X_test,
        y=y_test,
        batch_size=batch_size)
    y_train_pred = ann.predict(X_train)
    y_test_pred = ann.predict(X_test)

    # Show various scores
    from sklearn.metrics import r2_score
    from sklearn.metrics import mean_squared_error
    print("ANN train: {}".format(ann_train_loss))
    print("ANN test: {}".format(ann_test_loss))
    print("R2 score of a trivial predictor on train data:\t{:0.8f}".
          format(r2_score(y_train[1:], y_train[:-1])))
    print("R2 score of a trivial predictor on test data:\t{:0.8f}".
          format(r2_score(y_test[1:], y_test[:-1])))
    print("MSE of a trivial predictor on train data:\t{:0.8f}".
          format(mean_squared_error(y_train[1:], y_train[:-1])))
    print("MSE of a trivial predictor on test data:\t{:0.8f}".
          format(mean_squared_error(y_test[1:], y_test[:-1])))
    print("The R2 score on the Train set is:\t{:0.8f}".
          format(r2_score(y_train, y_train_pred)))
    print("The R2 score on the Test set is:\t{:0.8f}".
          format(r2_score(y_test, y_test_pred)))
    print("MSE of the trained ANN on train data:\t{:0.8f}".
          format(mean_squared_error(y_train, y_train_pred)))
    print("MSE of the trained ANN on test data:\t{:0.8f}".
          format(mean_squared_error(y_test, y_test_pred)))

    # show the data in a graph
    plt.figure(figsize=(20, 12))
    plt.subplot(1,2,1)
    plt.plot(range(test_split), train_data, label="train")
    plt.plot(range(test_split, len(df)), test_data, label="test")
    plt.plot(range(window, window + len(y_train_pred)),
             y_train_pred, label="trained")
    plt.plot(range(window + test_split, window + test_split + len(y_test_pred)),
             y_test_pred, label="test prediction")
    plt.title("Original data and ANN predictions")
    plt.xlabel("Observation")
    plt.ylabel("S&P500 Close Daily scaled")
    plt.legend()
    #plt.show()

    # graph Train and Validation loss evolution
    skip = 2  # Avoid autoscale issues
    #plt.figure(figsize=(10,12))
    plt.subplot(122)
    plt.plot(history.history["loss"][skip:], "g",
             label="Training loss")
    if (p["val_split"] != 0.0):
        plt.plot(history.history["val_loss"][skip:], "b",
                 label="Validation loss")
    plt.title("Loss evolution during training")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# %% [markdown]
# ##### Create and evaluate the ANN described by a chromosome

# %%
def evaluate_chromosome(chromosome, p=None, train_data=None, targets=None,
                        seen_fenotypes=None):
    """Build, train and evaluate an ANN represented by a chromosome
    Extract the fenotype from the chromosome
    If it has been previously evaluated return the loss immediately
    otherwise create train and evaluate the ann
    save the training and validation loss

    Args:
    chromosome: list of genes: each gene is a float that describes an
                ANN feature
    p: dict: of hyperparameters
    train_data: flat array-like: data for training
    targets: flat array-like: targets for training
    seen_fenotypes: dictionary: evaluated fenotypes and their losses

    Returns:
    (float,): Validation loss
    """

    # ensure reproducibility
    tf.random.set_seed(31416)  # Keras

    # extract fenotype
    fenotype = tuple(
        [int(chromosome[i] * p["range"][i] + p["min"][i])
        for i in range(p["ngenes"])])

    # set hyperparameters
    for i in range(p["ngenes"]):
        p[p["genes"][i]] = fenotype[i]

    # display fenotype
    for i, j in zip(p["genes"], fenotype):
        print(i, j, "", end="")
    print("")

    # avoid evaluating the same fenotype twice
    if fenotype in seen_fenotypes:
        return seen_fenotypes[fenotype][0],

    # Build the ANN
    model, history = create_ann(p, train_scaled, train_scaled)

    # extract and display training and validation loss
    val_loss = history.history["val_loss"][-1]
    loss = history.history["loss"][-1]
    print("Training error: {} Validation error: {}".format(loss, val_loss))
    seen_fenotypes[fenotype] = val_loss, loss
    return val_loss,

# %% [markdown]
# #### Create the fitness definition

# %%
# Fitness tries to maximize we need to use negative weight to minimize
#creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# %% [markdown]
# #### Define the rest of the genetic operators on the toolbox

# %%
toolbox = base.Toolbox()
toolbox.register("attr_float", random.random)
toolbox.register("individual", tools.initRepeat, creator.Individual,
                 toolbox.attr_float, n=p["ngenes"])
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

def checkBounds(min, max):
    """Decorator to adjust the gene value in case it is out of bounds

    Args:
    min: minimum value
    max: maximum value

    Returns:
    The function that checks bounds to decorate mate or mutate on the toolbox
    """

    def decorator(func):
        def wrapper(*args, **kargs):
            offspring = func(*args, **kargs)
            for child in offspring:
                for i in range(len(child)):
                    if child[i] > max:
                        child[i] = max
                    elif child[i] < min:
                        child[i] = min
            return offspring
        return wrapper
    return decorator


# mate by Alpha Blend
toolbox.register("mate", tools.cxBlend, alpha=p["alpha"])
# stay within [0,1)
toolbox.decorate("mate", checkBounds(0.0, 0.9999999999999999))
# mutate by gaussian perturbation
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=p["sigma"],
                 indpb=p["indpb"])
# stay within [0,1)
toolbox.decorate("mutate", checkBounds(0.0, 0.9999999999999999))
toolbox.register("select", tools.selTournament, tournsize=p["tournsize"])
# initialize seen list to avoid multiple evaluations
seen_fenotypes = {}
toolbox.register("evaluate", evaluate_chromosome, p=p, train_data=train_scaled,
                 targets=train_scaled, seen_fenotypes=seen_fenotypes)

# %% [markdown]
# ### The GA

# %% [markdown]
# #### Run the GA

# %%
# Ensure reproducibility
random.seed(31416) # DEAP uses random

# reset list to avoid multiple evaluations
seen_fenotypes = {}

population = toolbox.population(n=p["population"])
algorithms.eaSimple(population, toolbox, cxpb=p["cxpb"], mutpb=p["mutpb"],
                        ngen=p["ngen"], verbose=True)
# Out:
# Window 103 Neurons 31
# Training error: 3.4063999919453636e-05 Validation error: 0.0003923565964214504
# Window 132 Neurons 27
# Training error: 3.481811290839687e-05 Validation error: 5.903633064008318e-05
# Window 93 Neurons 23
# Training error: 3.648891652119346e-05 Validation error: 0.00020866526756435633
# Window 107 Neurons 22
# Training error: 3.437586929067038e-05 Validation error: 3.234265386709012e-05
# Window 3 Neurons 15
# Training error: 2.2647122023045085e-05 Validation error: 0.00040485235513187945
# Window 175 Neurons 21
# Training error: 4.332374010118656e-05 Validation error: 0.00024425191804766655
# Window 49 Neurons 19
# Training error: 2.785134711302817e-05 Validation error: 4.148561129113659e-05
# Window 75 Neurons 30
# Training error: 3.0770352168474346e-05 Validation error: 3.246691630920395e-05
# Window 109 Neurons 7
# Training error: 3.1260518881026655e-05 Validation error: 5.333252556738444e-05
# Window 199 Neurons 17
# Training error: 3.777621896006167e-05 Validation error: 3.948799712816253e-05
# Window 49 Neurons 26
# Training error: 2.9193424779805355e-05 Validation error: 4.402021295391023e-05
# Window 126 Neurons 19
# Training error: 3.724237467395142e-05 Validation error: 3.5366112570045516e-05
# Window 58 Neurons 2
# Training error: 3.705526978592388e-05 Validation error: 0.005324845667928457
# Window 105 Neurons 9
# Training error: 3.160170672344975e-05 Validation error: 5.859929297002964e-05
# Window 158 Neurons 17
# Training error: 3.659684080048464e-05 Validation error: 0.0001520321675343439
# Window 197 Neurons 3
# Training error: 3.753125201910734e-05 Validation error: 6.0135564126539975e-05
# Window 127 Neurons 30
# Training error: 3.4761189454002306e-05 Validation error: 0.00019297019753139466
# Window 115 Neurons 6
# Training error: 3.1834533729124814e-05 Validation error: 3.4343400329817086e-05
# Window 92 Neurons 4
# Training error: 4.145879938732833e-05 Validation error: 0.005488586146384478
# Window 163 Neurons 9
# Training error: 3.432787343626842e-05 Validation error: 3.4238037187606096e-05
# Window 188 Neurons 10
# Training error: 3.937893416150473e-05 Validation error: 0.00010086207475978881
# Window 132 Neurons 8
# Training error: 3.401974754524417e-05 Validation error: 4.194748544250615e-05
# Window 41 Neurons 18
# Training error: 2.6268611691193655e-05 Validation error: 2.986348408740014e-05
# Window 18 Neurons 25
# Training error: 2.5787709091673605e-05 Validation error: 2.4453231162624434e-05
# Window 186 Neurons 26
# Training error: 4.30005275120493e-05 Validation error: 0.00011167010961798951
# Window 100 Neurons 22
# Training error: 3.6137858842266724e-05 Validation error: 5.2760704420506954e-05
# Window 196 Neurons 29
# Training error: 3.613889202824794e-05 Validation error: 0.00013155963097233325
# Window 109 Neurons 23
# Training error: 4.553246253635734e-05 Validation error: 4.9251349992118776e-05
# Window 119 Neurons 18
# Training error: 3.513523188303225e-05 Validation error: 4.8625788622302935e-05
# Window 160 Neurons 27
# Training error: 4.2625568312359974e-05 Validation error: 0.0017575237434357405
# Window 128 Neurons 24
# Training error: 3.288284278823994e-05 Validation error: 3.125530565739609e-05
# Window 92 Neurons 4
# Window 48 Neurons 12
# Training error: 2.853578007488977e-05 Validation error: 2.768308149825316e-05
# Window 132 Neurons 13
# Training error: 3.8758767914259806e-05 Validation error: 3.6241217458155006e-05
# Window 195 Neurons 12
# Training error: 3.796366218011826e-05 Validation error: 0.0034572340082377195
# Window 125 Neurons 27
# Training error: 3.415273386053741e-05 Validation error: 5.794559547211975e-05
# Window 101 Neurons 8
# Training error: 3.3479744161013514e-05 Validation error: 3.9920407289173454e-05
# Window 16 Neurons 20
# Training error: 2.437068906147033e-05 Validation error: 8.560867718188092e-05
# Window 154 Neurons 15
# Training error: 3.6241570342099294e-05 Validation error: 5.929858889430761e-05
# Window 157 Neurons 11
# Training error: 3.6005800211569294e-05 Validation error: 4.035025631310418e-05
# Window 123 Neurons 21
# Training error: 3.685307819978334e-05 Validation error: 4.6460227167699486e-05
# Window 75 Neurons 17
# Training error: 3.438402927713469e-05 Validation error: 2.7000747650163248e-05
# Window 143 Neurons 18
# Training error: 3.671769081847742e-05 Validation error: 3.418983396841213e-05
# Window 121 Neurons 18
# Training error: 3.709522570716217e-05 Validation error: 3.244670369895175e-05
# Window 171 Neurons 16
# Training error: 3.9710455894237384e-05 Validation error: 9.362729906570166e-05
# Window 101 Neurons 8
# Window 61 Neurons 29
# Training error: 2.734844383667223e-05 Validation error: 0.0014323379145935178
# Window 75 Neurons 18
# Training error: 3.156703314743936e-05 Validation error: 2.77941653621383e-05
# Window 128 Neurons 24
# Window 133 Neurons 9
# Training error: 3.3779695513658226e-05 Validation error: 3.300866956124082e-05
# Window 77 Neurons 29
# Training error: 3.445193942752667e-05 Validation error: 4.8889178287936375e-05
# Window 189 Neurons 20
# Training error: 4.009117401437834e-05 Validation error: 5.93192562519107e-05
# Window 159 Neurons 10
# Training error: 3.8615904486505315e-05 Validation error: 0.00018295011250302196
# Window 85 Neurons 21
# Training error: 3.860326251015067e-05 Validation error: 0.00017200890579260886
# Window 17 Neurons 28
# Training error: 2.506007695046719e-05 Validation error: 2.9036440537311137e-05
# Window 76 Neurons 21
# Training error: 4.4063450332032517e-05 Validation error: 8.841838280204684e-05
# Window 196 Neurons 12
# Training error: 3.9727256080368534e-05 Validation error: 4.569191514747217e-05
# Window 21 Neurons 23
# Training error: 2.544742528698407e-05 Validation error: 2.8666117941611446e-05
# Window 41 Neurons 13
# Training error: 2.801246773742605e-05 Validation error: 2.9183554943301715e-05
# Window 61 Neurons 16
# Training error: 3.067769648623653e-05 Validation error: 0.0015624092193320394
# Window 90 Neurons 4
# Training error: 3.521956750773825e-05 Validation error: 0.005406577605754137
# Window 139 Neurons 23
# Training error: 4.459384217625484e-05 Validation error: 0.00013764614413958043
# Window 135 Neurons 12
# Training error: 3.8813745049992576e-05 Validation error: 0.0003002452140208334
# Window 71 Neurons 25
# Training error: 3.3366548450430855e-05 Validation error: 2.9892356906202622e-05
# Window 176 Neurons 4
# Training error: 5.3604875574819744e-05 Validation error: 0.005306676961481571
# Window 135 Neurons 17
# Training error: 4.1474741010461e-05 Validation error: 0.00047156622167676687
# Window 79 Neurons 26
# Training error: 3.008886233146768e-05 Validation error: 6.492927059298381e-05
# Window 197 Neurons 7
# Training error: 3.686143463710323e-05 Validation error: 5.794708340545185e-05
# Window 18 Neurons 16
# Training error: 2.595301702967845e-05 Validation error: 4.38605020463001e-05
# Window 149 Neurons 21
# Training error: 5.0587987061589956e-05 Validation error: 8.234237611759454e-05
# Window 43 Neurons 16
# Training error: 3.014018693647813e-05 Validation error: 2.6678695576265454e-05
# Window 157 Neurons 29
# Training error: 3.576643211999908e-05 Validation error: 4.434231959749013e-05
# Window 53 Neurons 19
# Training error: 2.7067653718404472e-05 Validation error: 2.6855099349631928e-05
# Window 37 Neurons 31
# Training error: 2.9758610253338702e-05 Validation error: 2.8845535780419596e-05
# Window 16 Neurons 25
# Training error: 2.4456257960991934e-05 Validation error: 7.607937004650012e-05
# gen	nevals
# 0  	75
# Window 201 Neurons 6
# Training error: 3.9378715882776305e-05 Validation error: 0.00013925090024713427
# Window 102 Neurons 7
# Training error: 2.9816888854838908e-05 Validation error: 3.0205324947019108e-05
# Window 103 Neurons 2
# Training error: 0.004162533208727837 Validation error: 0.05364013835787773
# Window 201 Neurons 22
# Training error: 3.8303227483993396e-05 Validation error: 9.875564137473702e-05
# Window 163 Neurons 9
# Window 157 Neurons 11
# Window 91 Neurons 27
# Training error: 3.185028981533833e-05 Validation error: 4.764650293509476e-05
# Window 53 Neurons 11
# Training error: 2.733850669756066e-05 Validation error: 2.6915486159850843e-05
# Window 96 Neurons 25
# Training error: 3.624122473411262e-05 Validation error: 3.1623505492461845e-05
# Window 37 Neurons 25
# Training error: 3.1022736948216334e-05 Validation error: 4.3819061829708517e-05
# Window 55 Neurons 28
# Training error: 3.1342304282588884e-05 Validation error: 0.00018374000501353294
# Window 70 Neurons 23
# Training error: 3.3514192182337865e-05 Validation error: 0.0003467730712145567
# Window 39 Neurons 20
# Training error: 2.6408097255625762e-05 Validation error: 2.4854358343873173e-05
# Window 42 Neurons 27
# Training error: 2.7997366487397812e-05 Validation error: 4.032386641483754e-05
# Window 126 Neurons 19
# Window 29 Neurons 19
# Training error: 2.5750416170922108e-05 Validation error: 2.8510112315416336e-05
# Window 152 Neurons 15
# Training error: 3.3122723834821954e-05 Validation error: 7.203654240584001e-05
# Window 131 Neurons 8
# Training error: 3.509602538542822e-05 Validation error: 0.00029283505864441395
# Window 106 Neurons 23
# Training error: 3.724678390426561e-05 Validation error: 5.2589843107853085e-05
# Window 121 Neurons 21
# Training error: 4.041016291012056e-05 Validation error: 7.475074380636215e-05
# Window 54 Neurons 23
# Training error: 2.9278469810378738e-05 Validation error: 3.972782724304125e-05
# Window 102 Neurons 10
# Training error: 3.201896834070794e-05 Validation error: 3.0359316951944493e-05
# Window 162 Neurons 8
# Training error: 3.6536181141855195e-05 Validation error: 4.400991747388616e-05
# Window 177 Neurons 24
# Training error: 3.865778853651136e-05 Validation error: 0.00012156003504060209
# Window 140 Neurons 21
# Training error: 4.136934148846194e-05 Validation error: 4.1326155042042956e-05
# Window 145 Neurons 26
# Training error: 4.0286220610141754e-05 Validation error: 3.543239654391073e-05
# Window 2 Neurons 26
# Training error: 2.2301299395621754e-05 Validation error: 0.0004189635219518095
# Window 66 Neurons 24
# Training error: 3.2770258258096874e-05 Validation error: 5.104039883008227e-05
# Window 133 Neurons 25
# Training error: 3.4823424357455224e-05 Validation error: 5.416640124167316e-05
# Window 39 Neurons 21
# Training error: 2.6661844458431005e-05 Validation error: 3.782560452236794e-05
# Window 110 Neurons 18
# Training error: 3.2401116186520085e-05 Validation error: 3.0813222110737115e-05
# Window 110 Neurons 17
# Training error: 3.868900967063382e-05 Validation error: 3.636755354818888e-05
# Window 117 Neurons 9
# Training error: 3.2327661756426096e-05 Validation error: 0.00031355427927337587
# Window 78 Neurons 23
# Training error: 3.530360845616087e-05 Validation error: 2.9898885259171948e-05
# Window 142 Neurons 19
# Training error: 3.809395639109425e-05 Validation error: 0.00019087980035692453
# Window 122 Neurons 26
# Training error: 3.412213482079096e-05 Validation error: 4.234488733345643e-05
# Window 141 Neurons 25
# Training error: 3.7161742511671036e-05 Validation error: 8.597945998189971e-05
# Window 166 Neurons 18
# Training error: 3.7136363971512765e-05 Validation error: 4.186614023637958e-05
# Window 189 Neurons 28
# Training error: 4.249535413691774e-05 Validation error: 4.004071524832398e-05
# Window 163 Neurons 9
# Window 143 Neurons 18
# Window 19 Neurons 24
# Training error: 2.468567981850356e-05 Validation error: 2.150225918740034e-05
# Window 43 Neurons 18
# Training error: 2.7627549570752308e-05 Validation error: 2.7529387807589956e-05
# Window 35 Neurons 22
# Training error: 2.915731238317676e-05 Validation error: 2.3798593247192912e-05
# Window 32 Neurons 16
# Training error: 2.5987625122070312e-05 Validation error: 2.5795618057600223e-05
# Window 164 Neurons 20
# Training error: 3.499401282169856e-05 Validation error: 5.6931294238893315e-05
# Window 69 Neurons 22
# Training error: 3.342153286212124e-05 Validation error: 4.118727883906104e-05
# Window 63 Neurons 15
# Training error: 3.194275632267818e-05 Validation error: 2.8710772312479094e-05
# Window 112 Neurons 12
# Training error: 3.676486812764779e-05 Validation error: 6.156319432193413e-05
# 1  	49
# Window 59 Neurons 30
# Training error: 2.951793430838734e-05 Validation error: 0.0001527956483187154
# Window 51 Neurons 21
# Training error: 2.8521813874249347e-05 Validation error: 7.864864164730534e-05
# Window 126 Neurons 19
# Window 126 Neurons 19
# Window 193 Neurons 18
# Training error: 3.909999577444978e-05 Validation error: 0.0009788555325940251
# Window 195 Neurons 26
# Training error: 4.084256215719506e-05 Validation error: 0.0032732842955738306
# Window 39 Neurons 20
# Window 35 Neurons 22
# Window 113 Neurons 9
# Training error: 3.223260137019679e-05 Validation error: 5.3500334615819156e-05
# Window 10 Neurons 19
# Training error: 2.2777760023018345e-05 Validation error: 9.882897575153038e-05
# Window 157 Neurons 9
# Training error: 3.546815787558444e-05 Validation error: 6.891261000419036e-05
# Window 157 Neurons 11
# Window 11 Neurons 7
# Training error: 2.3481288735638373e-05 Validation error: 2.5661189283709973e-05
# Window 108 Neurons 25
# Training error: 3.505986023810692e-05 Validation error: 3.90242385037709e-05
# Window 118 Neurons 24
# Training error: 3.390934944036417e-05 Validation error: 8.882236579665914e-05
# Window 118 Neurons 10
# Training error: 3.1744566513225436e-05 Validation error: 8.043575508054346e-05
# Window 50 Neurons 21
# Training error: 2.7949054128839634e-05 Validation error: 0.0001365386415272951
# Window 37 Neurons 19
# Training error: 2.9857530535082333e-05 Validation error: 2.863746340153739e-05
# Window 62 Neurons 7
# Training error: 3.073938933084719e-05 Validation error: 4.1105147829512134e-05
# Window 88 Neurons 12
# Training error: 3.024461148015689e-05 Validation error: 8.88123395270668e-05
# Window 158 Neurons 19
# Training error: 3.233952520531602e-05 Validation error: 3.733178527909331e-05
# Window 13 Neurons 18
# Training error: 2.3487136786570773e-05 Validation error: 2.2127720512798987e-05
# Window 201 Neurons 17
# Training error: 4.169579187873751e-05 Validation error: 0.00012185414379928261
# Window 34 Neurons 17
# Training error: 2.8459955501602963e-05 Validation error: 3.423594171181321e-05
# Window 32 Neurons 5
# Training error: 2.6678690119297244e-05 Validation error: 2.75693219009554e-05
# Window 112 Neurons 24
# Training error: 3.370569538674317e-05 Validation error: 3.975423896918073e-05
# Window 75 Neurons 30
# Window 32 Neurons 16
# Window 29 Neurons 21
# Training error: 2.4997376385726966e-05 Validation error: 2.825229057634715e-05
# Window 32 Neurons 22
# Training error: 3.0085284379310906e-05 Validation error: 2.703800237213727e-05
# Window 118 Neurons 23
# Training error: 4.443492798600346e-05 Validation error: 0.0001198205936816521
# Window 97 Neurons 28
# Training error: 3.425983231863938e-05 Validation error: 8.058437379077077e-05
# Window 53 Neurons 11
# Window 95 Neurons 13
# Training error: 3.7984187656547874e-05 Validation error: 0.0006628113915212452
# Window 131 Neurons 11
# Training error: 3.5156426747562364e-05 Validation error: 0.0003141269844491035
# Window 121 Neurons 18
# Window 44 Neurons 8
# Training error: 2.9599559638882056e-05 Validation error: 4.424053258844651e-05
# Window 78 Neurons 23
# Window 201 Neurons 17
# Window 26 Neurons 18
# Training error: 2.350335671508219e-05 Validation error: 6.209826096892357e-05
# Window 146 Neurons 29
# Training error: 4.242177601554431e-05 Validation error: 5.07842778461054e-05
# Window 161 Neurons 7
# Training error: 3.274511982453987e-05 Validation error: 0.0017163977026939392
# 2  	42
# Window 22 Neurons 24
# Training error: 2.4042989025474526e-05 Validation error: 2.2265354346018285e-05
# Window 29 Neurons 21
# Window 11 Neurons 19
# Training error: 2.315733399882447e-05 Validation error: 0.00010584224946796894
# Window 35 Neurons 10
# Training error: 3.123407805105671e-05 Validation error: 3.2546158763580024e-05
# Window 32 Neurons 22
# Window 19 Neurons 24
# Window 15 Neurons 10
# Training error: 2.323140506632626e-05 Validation error: 4.514811735134572e-05
# Window 15 Neurons 21
# Training error: 2.383691753493622e-05 Validation error: 2.5162758902297355e-05
# Window 145 Neurons 31
# Training error: 3.6053719668416306e-05 Validation error: 3.409401688259095e-05
# Window 145 Neurons 26
# Window 105 Neurons 20
# Training error: 3.2140014809556305e-05 Validation error: 9.851601498667151e-05
# Window 201 Neurons 22
# Window 41 Neurons 30
# Training error: 2.5477233066339977e-05 Validation error: 2.538053013267927e-05
# Window 68 Neurons 16
# Training error: 2.9828172046109103e-05 Validation error: 4.663404615712352e-05
# Window 40 Neurons 9
# Training error: 2.5762617951841094e-05 Validation error: 2.5453828129684553e-05
# Window 30 Neurons 17
# Training error: 2.718343421292957e-05 Validation error: 3.420390930841677e-05
# Window 122 Neurons 23
# Training error: 3.803305662586354e-05 Validation error: 5.003277328796685e-05
# Window 38 Neurons 22
# Training error: 3.097370426985435e-05 Validation error: 2.5759167328942567e-05
# Window 93 Neurons 15
# Training error: 3.578722316888161e-05 Validation error: 0.00019493770378176123
# Window 87 Neurons 18
# Training error: 3.266022395109758e-05 Validation error: 3.8118432712508366e-05
# Window 53 Neurons 19
# Window 39 Neurons 20
# Window 13 Neurons 18
# Window 31 Neurons 26
# Training error: 2.7060232241638005e-05 Validation error: 0.00011452272156020626
# Window 43 Neurons 22
# Training error: 3.0379887903109193e-05 Validation error: 2.7434520234237425e-05
# Window 51 Neurons 16
# Training error: 2.7248202968621626e-05 Validation error: 6.605614180443808e-05
# Window 32 Neurons 18
# Training error: 2.5296732928836718e-05 Validation error: 2.5498526156297885e-05
# Window 54 Neurons 13
# Training error: 2.8510563424788415e-05 Validation error: 5.6712175137363374e-05
# Window 52 Neurons 17
# Training error: 3.056470086448826e-05 Validation error: 0.0001058292982634157
# Window 74 Neurons 24
# Training error: 3.0935596441850066e-05 Validation error: 2.6918653020402417e-05
# Window 57 Neurons 18
# Training error: 2.953995681309607e-05 Validation error: 0.00021970616944599897
# Window 48 Neurons 12
# Window 52 Neurons 11
# Training error: 2.7296146072330885e-05 Validation error: 5.3930034482618794e-05
# Window 33 Neurons 18
# Training error: 2.509625301172491e-05 Validation error: 2.656670767464675e-05
# Window 15 Neurons 22
# Training error: 2.3469307052437216e-05 Validation error: 3.0010705813765526e-05
# Window 15 Neurons 20
# Training error: 2.4047953047556803e-05 Validation error: 2.3019778382149525e-05
# Window 35 Neurons 18
# Training error: 2.6567875465843827e-05 Validation error: 2.3418400814989582e-05
# Window 49 Neurons 8
# Training error: 2.7344603950041346e-05 Validation error: 2.6307492589694448e-05
# Window 90 Neurons 19
# Training error: 3.330166873638518e-05 Validation error: 0.0001077555789379403
# Window 20 Neurons 7
# Training error: 2.6954727218253538e-05 Validation error: 3.0834024073556066e-05
# Window 11 Neurons 24
# Training error: 2.2652104235021397e-05 Validation error: 2.3721877369098365e-05
# Window 102 Neurons 22
# Training error: 3.163734800182283e-05 Validation error: 2.8547305191750638e-05
# Window 34 Neurons 8
# Training error: 2.710451190068852e-05 Validation error: 3.339292015880346e-05
# Window 39 Neurons 15
# Training error: 2.5835781343630515e-05 Validation error: 2.9156475648051128e-05
# Window 44 Neurons 19
# Training error: 2.8373719032970257e-05 Validation error: 3.277241194155067e-05
# Window 91 Neurons 21
# Training error: 3.3685526432236657e-05 Validation error: 7.430034020217136e-05
# Window 76 Neurons 23
# Training error: 3.4728065656963736e-05 Validation error: 6.188629049574956e-05
# Window 97 Neurons 8
# Training error: 3.055600609513931e-05 Validation error: 4.036151585751213e-05
# Window 104 Neurons 20
# Training error: 3.0227729439502582e-05 Validation error: 0.0002389333094470203
# 3  	49
# Window 39 Neurons 20
# Window 39 Neurons 20
# Window 13 Neurons 19
# Training error: 2.4433415092062205e-05 Validation error: 2.187769132433459e-05
# Window 23 Neurons 24
# Training error: 2.4249104171758518e-05 Validation error: 2.2935526430956088e-05
# Window 33 Neurons 21
# Training error: 2.6395848180982284e-05 Validation error: 2.2451653421740048e-05
# Window 32 Neurons 19
# Training error: 2.814945582940709e-05 Validation error: 3.06498259305954e-05
# Window 34 Neurons 18
# Training error: 2.5137765987892635e-05 Validation error: 3.585600643418729e-05
# Window 18 Neurons 24
# Training error: 2.432646397210192e-05 Validation error: 2.063110332528595e-05
# Window 40 Neurons 23
# Training error: 2.951058922917582e-05 Validation error: 3.4477474400773644e-05
# Window 17 Neurons 23
# Training error: 2.4932754968176596e-05 Validation error: 3.781272243941203e-05
# Window 39 Neurons 20
# Window 13 Neurons 18
# Window 32 Neurons 20
# Training error: 2.490223960194271e-05 Validation error: 2.6354720830568112e-05
# Window 39 Neurons 19
# Training error: 2.7981444873148575e-05 Validation error: 3.14044882543385e-05
# Window 30 Neurons 16
# Training error: 2.537913496780675e-05 Validation error: 3.093310442636721e-05
# Window 60 Neurons 24
# Training error: 2.835151826729998e-05 Validation error: 2.534417581046e-05
# Window 33 Neurons 24
# Training error: 2.534598024794832e-05 Validation error: 2.483941898390185e-05
# Window 17 Neurons 10
# Training error: 2.378586941631511e-05 Validation error: 2.2244608771870844e-05
# Window 47 Neurons 17
# Training error: 2.780978502414655e-05 Validation error: 2.850943201337941e-05
# Window 50 Neurons 30
# Training error: 2.844590380846057e-05 Validation error: 0.00012324991985224187
# Window 40 Neurons 13
# Training error: 2.805041367537342e-05 Validation error: 2.740537456702441e-05
# Window 27 Neurons 21
# Training error: 2.5909252144629136e-05 Validation error: 2.4595452487119474e-05
# Window 30 Neurons 20
# Training error: 2.6125706426682882e-05 Validation error: 3.2523490517633036e-05
# Window 39 Neurons 23
# Training error: 2.9527336664614268e-05 Validation error: 2.6661173251341097e-05
# Window 39 Neurons 20
# Window 15 Neurons 20
# Window 24 Neurons 19
# Training error: 2.5673298296169378e-05 Validation error: 2.386110463703517e-05
# Window 28 Neurons 19
# Training error: 2.6575640731607564e-05 Validation error: 0.00026091266772709787
# Window 20 Neurons 18
# Training error: 2.4354203560505994e-05 Validation error: 3.0287519621197134e-05
# Window 25 Neurons 21
# Training error: 2.556366234784946e-05 Validation error: 4.258643093635328e-05
# Window 14 Neurons 7
# Training error: 2.480728471709881e-05 Validation error: 9.86032682703808e-05
# Window 71 Neurons 24
# Training error: 3.202429070370272e-05 Validation error: 4.352205723989755e-05
# Window 11 Neurons 23
# Training error: 2.3189697458292358e-05 Validation error: 5.478006642078981e-05
# Window 39 Neurons 21
# Window 2 Neurons 24
# Training error: 2.220487476733979e-05 Validation error: 0.00044534096377901733
# Window 2 Neurons 18
# Training error: 2.208009027526714e-05 Validation error: 0.00032568053575232625
# Window 39 Neurons 20
# Window 39 Neurons 20
# Window 19 Neurons 19
# Training error: 2.5636649297666736e-05 Validation error: 2.6523757696850225e-05
# Window 15 Neurons 24
# Training error: 2.3143296857597306e-05 Validation error: 2.8777896659448743e-05
# Window 28 Neurons 21
# Training error: 2.5738825570442714e-05 Validation error: 0.00026181526482105255
# Window 39 Neurons 20
# Window 33 Neurons 23
# Training error: 2.6136127416975796e-05 Validation error: 2.6893678295891732e-05
# Window 29 Neurons 18
# Training error: 2.5363209715578705e-05 Validation error: 3.125052899122238e-05
# Window 31 Neurons 22
# Training error: 2.7804910132545047e-05 Validation error: 8.117625111481175e-05
# Window 41 Neurons 17
# Training error: 2.6453646569279954e-05 Validation error: 3.675957123050466e-05
# Window 26 Neurons 7
# Training error: 3.011115222761873e-05 Validation error: 5.317649993230589e-05
# Window 17 Neurons 18
# Training error: 2.3614564270246774e-05 Validation error: 2.81871143670287e-05
# Window 33 Neurons 16
# Training error: 2.7337366191204637e-05 Validation error: 3.0677561881020665e-05
# Window 39 Neurons 12
# Training error: 2.7673564545693807e-05 Validation error: 2.5975798052968457e-05
# Window 7 Neurons 16
# Training error: 2.3459047952201217e-05 Validation error: 0.0005580278229899704
# Window 47 Neurons 9
# Training error: 3.1419232982443646e-05 Validation error: 3.342993659316562e-05
# Window 19 Neurons 23
# Training error: 2.592138662294019e-05 Validation error: 2.140441574738361e-05
# Window 22 Neurons 24
# 4  	54
# Window 50 Neurons 16
# Training error: 2.8078999093850143e-05 Validation error: 0.00011167601041961461
# Window 32 Neurons 15
# Training error: 2.7509160645422526e-05 Validation error: 2.7545727789402008e-05
# Window 23 Neurons 24
# Window 19 Neurons 24
# Window 35 Neurons 19
# Training error: 2.7567311917664483e-05 Validation error: 3.748323069885373e-05
# Window 14 Neurons 19
# Training error: 2.5904291760525666e-05 Validation error: 2.5455672584939748e-05
# Window 19 Neurons 24
# Window 22 Neurons 21
# Training error: 2.5677994926809333e-05 Validation error: 3.948737867176533e-05
# Window 19 Neurons 22
# Training error: 2.5258548703277484e-05 Validation error: 2.8556352845043875e-05
# Window 33 Neurons 21
# Window 27 Neurons 21
# Window 35 Neurons 19
# Window 35 Neurons 20
# Training error: 2.6424011593917385e-05 Validation error: 2.4995355488499627e-05
# Window 32 Neurons 18
# Window 24 Neurons 24
# Training error: 2.3866699848440476e-05 Validation error: 2.6325074941269122e-05
# Window 19 Neurons 9
# Training error: 2.6170437195105478e-05 Validation error: 2.3156791939982213e-05
# Window 17 Neurons 25
# Training error: 2.422290708636865e-05 Validation error: 3.402542643016204e-05
# Window 34 Neurons 20
# Training error: 2.5868121156236157e-05 Validation error: 3.936910070478916e-05
# Window 37 Neurons 21
# Training error: 2.909973954956513e-05 Validation error: 2.5825307602644898e-05
# Window 34 Neurons 26
# Training error: 2.8466492949519306e-05 Validation error: 2.5576617190381512e-05
# Window 24 Neurons 10
# Training error: 2.819477413140703e-05 Validation error: 3.493654730846174e-05
# Window 39 Neurons 20
# Window 26 Neurons 24
# Training error: 2.4482491426169872e-05 Validation error: 5.21363690495491e-05
# Window 25 Neurons 23
# Training error: 2.7355667043593712e-05 Validation error: 2.7892334401258267e-05
# Window 39 Neurons 20
# Window 39 Neurons 20
# Window 39 Neurons 20
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 40 Neurons 18
# Training error: 2.9464967155945487e-05 Validation error: 2.6635028916643932e-05
# Window 42 Neurons 20
# Training error: 2.6767478630063124e-05 Validation error: 2.494617729098536e-05
# Window 35 Neurons 12
# Training error: 2.6111574698006734e-05 Validation error: 2.3278493245015852e-05
# Window 20 Neurons 19
# Training error: 2.6559229809208773e-05 Validation error: 4.301164153730497e-05
# Window 39 Neurons 14
# Training error: 2.6990250262315385e-05 Validation error: 2.7974498152616434e-05
# Window 19 Neurons 28
# Training error: 2.523823241062928e-05 Validation error: 2.9464821636793204e-05
# Window 18 Neurons 28
# Training error: 2.6449113647686318e-05 Validation error: 2.3253553081303835e-05
# Window 36 Neurons 20
# Training error: 2.5964814994949847e-05 Validation error: 2.4010245397221297e-05
# Window 24 Neurons 22
# Training error: 2.5031742552528158e-05 Validation error: 3.127676245640032e-05
# Window 21 Neurons 21
# Training error: 2.5258368623326533e-05 Validation error: 5.1861305109923705e-05
# Window 32 Neurons 25
# Training error: 2.6304151106160134e-05 Validation error: 2.503069117665291e-05
# Window 25 Neurons 19
# Training error: 2.7072968805441633e-05 Validation error: 3.006573206221219e-05
# Window 21 Neurons 22
# Training error: 2.477137604728341e-05 Validation error: 3.691896199597977e-05
# Window 28 Neurons 22
# Training error: 2.5468973035458475e-05 Validation error: 0.0004063206724822521
# Window 11 Neurons 19
# Window 41 Neurons 20
# Training error: 2.504199255781714e-05 Validation error: 4.0701881516724825e-05
# Window 22 Neurons 23
# Training error: 2.6911116947303526e-05 Validation error: 3.2703133911127225e-05
# Window 35 Neurons 18
# Window 36 Neurons 20
# Window 35 Neurons 20
# Window 24 Neurons 9
# Training error: 2.3958444216987118e-05 Validation error: 3.2517436920898035e-05
# Window 31 Neurons 21
# Training error: 2.7433694413048215e-05 Validation error: 6.314367055892944e-05
# Window 13 Neurons 21
# Training error: 2.3396620235871524e-05 Validation error: 1.9962912119808607e-05
# Window 18 Neurons 23
# Training error: 2.5995997930294834e-05 Validation error: 5.896788206882775e-05
# 5  	53
# Window 19 Neurons 24
# Window 17 Neurons 19
# Training error: 2.51209730777191e-05 Validation error: 3.7972804420860484e-05
# Window 6 Neurons 19
# Training error: 2.2951582650421187e-05 Validation error: 0.00011402167729102075
# Window 19 Neurons 24
# Window 19 Neurons 23
# Window 19 Neurons 22
# Window 22 Neurons 20
# Training error: 2.7067424525739625e-05 Validation error: 5.56750746909529e-05
# Window 12 Neurons 22
# Training error: 2.3997070456971414e-05 Validation error: 9.682434756541625e-05
# Window 29 Neurons 14
# Training error: 2.5487965103820898e-05 Validation error: 2.9875742256990634e-05
# Window 30 Neurons 18
# Training error: 2.562054396548774e-05 Validation error: 3.154280784656294e-05
# Window 23 Neurons 26
# Training error: 2.651408067322336e-05 Validation error: 2.6516150683164597e-05
# Window 19 Neurons 24
# Window 23 Neurons 23
# Training error: 2.7210693588131107e-05 Validation error: 3.208080306649208e-05
# Window 19 Neurons 20
# Training error: 2.5221794203389436e-05 Validation error: 2.4176417355192825e-05
# Window 41 Neurons 24
# Training error: 2.453822162351571e-05 Validation error: 3.700856905197725e-05
# Window 18 Neurons 20
# Training error: 2.590540134406183e-05 Validation error: 3.279044904047623e-05
# Window 23 Neurons 22
# Training error: 2.6834490199689753e-05 Validation error: 2.99097355309641e-05
# Window 35 Neurons 23
# Training error: 2.6503616027184762e-05 Validation error: 2.495629269105848e-05
# Window 28 Neurons 22
# Window 39 Neurons 20
# Window 19 Neurons 24
# Window 13 Neurons 21
# Window 39 Neurons 20
# Window 39 Neurons 20
# Window 39 Neurons 21
# Window 38 Neurons 28
# Training error: 3.13259479298722e-05 Validation error: 2.295510239491705e-05
# Window 18 Neurons 22
# Training error: 2.492550811439287e-05 Validation error: 5.371740917325951e-05
# Window 17 Neurons 22
# Training error: 2.3557284293929115e-05 Validation error: 2.299965126439929e-05
# Window 14 Neurons 22
# Training error: 2.3721460820524953e-05 Validation error: 4.2328276322223246e-05
# Window 31 Neurons 21
# Window 28 Neurons 18
# Training error: 2.6880208679358475e-05 Validation error: 0.0003152626159135252
# Window 2 Neurons 19
# Training error: 2.2259075194597244e-05 Validation error: 2.100701749441214e-05
# Window 18 Neurons 25
# Window 3 Neurons 30
# Training error: 2.3084172426024452e-05 Validation error: 0.0003179180494043976
# Window 4 Neurons 19
# Training error: 2.3027627321425825e-05 Validation error: 7.844233914511278e-05
# Window 33 Neurons 19
# Training error: 2.8059659598511644e-05 Validation error: 3.595669477363117e-05
# Window 13 Neurons 21
# Window 13 Neurons 18
# Window 37 Neurons 26
# Training error: 3.079188536503352e-05 Validation error: 2.5814257242018357e-05
# Window 39 Neurons 25
# Training error: 3.0357472496689297e-05 Validation error: 2.6272264221915975e-05
# Window 30 Neurons 25
# Training error: 2.5818437279667705e-05 Validation error: 4.058564081788063e-05
# Window 24 Neurons 19
# Window 32 Neurons 21
# Training error: 2.612090975162573e-05 Validation error: 2.38989796343958e-05
# Window 40 Neurons 21
# Training error: 2.5489198378636502e-05 Validation error: 2.3260596208274364e-05
# Window 23 Neurons 21
# Training error: 2.5331439246656373e-05 Validation error: 2.1662874132744037e-05
# Window 34 Neurons 23
# Training error: 2.8103002478019334e-05 Validation error: 2.9662103770533577e-05
# Window 36 Neurons 23
# Training error: 2.695767216209788e-05 Validation error: 2.812436650856398e-05
# Window 39 Neurons 21
# Window 25 Neurons 8
# Training error: 2.7062424123869278e-05 Validation error: 4.737824201583862e-05
# Window 32 Neurons 16
# Window 35 Neurons 24
# Training error: 2.513755316613242e-05 Validation error: 2.201948154834099e-05
# Window 45 Neurons 24
# Training error: 2.657036566233728e-05 Validation error: 6.84248807374388e-05
# Window 19 Neurons 24
# 6  	53
# Window 21 Neurons 22
# Window 12 Neurons 23
# Training error: 2.383688661211636e-05 Validation error: 6.1034384998492897e-05
# Window 18 Neurons 22
# Window 15 Neurons 23
# Training error: 2.506694545445498e-05 Validation error: 3.813381408690475e-05
# Window 6 Neurons 17
# Training error: 2.2610458472627215e-05 Validation error: 0.00012185366358608007
# Window 36 Neurons 21
# Training error: 2.5848097720881924e-05 Validation error: 2.3010816221358255e-05
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 19 Neurons 21
# Training error: 2.4218543330789544e-05 Validation error: 2.2056350644561462e-05
# Window 13 Neurons 23
# Training error: 2.3671249437029473e-05 Validation error: 2.987276457133703e-05
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 23 Neurons 21
# Window 60 Neurons 23
# Training error: 2.9425116736092605e-05 Validation error: 0.00011642085883067921
# Window 3 Neurons 14
# Training error: 2.2566260668099858e-05 Validation error: 0.000601596781052649
# Window 28 Neurons 19
# Window 37 Neurons 26
# Window 16 Neurons 19
# Training error: 2.463247255946044e-05 Validation error: 6.334131467156112e-05
# Window 35 Neurons 11
# Training error: 2.68288204097189e-05 Validation error: 2.899540231737774e-05
# Window 23 Neurons 22
# Window 32 Neurons 22
# Window 20 Neurons 23
# Training error: 2.7423910069046542e-05 Validation error: 5.8964320487575606e-05
# Window 23 Neurons 20
# Training error: 2.552680962253362e-05 Validation error: 2.256501466035843e-05
# Window 19 Neurons 23
# Window 19 Neurons 24
# Window 20 Neurons 23
# Window 32 Neurons 22
# Window 19 Neurons 20
# Window 19 Neurons 13
# Training error: 2.3980193873285316e-05 Validation error: 2.1458447008626536e-05
# Window 42 Neurons 23
# Training error: 2.8406293495208956e-05 Validation error: 3.488832589937374e-05
# Window 35 Neurons 31
# Training error: 2.6418907509651035e-05 Validation error: 2.2168882424011827e-05
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 19 Neurons 29
# Training error: 2.3384940504911356e-05 Validation error: 2.0273320842534304e-05
# Window 19 Neurons 11
# Training error: 2.599519029899966e-05 Validation error: 2.7567226425162517e-05
# Window 19 Neurons 22
# Window 19 Neurons 24
# Window 19 Neurons 23
# Window 17 Neurons 18
# Window 15 Neurons 25
# Training error: 2.4262531951535493e-05 Validation error: 2.2427137082559057e-05
# Window 19 Neurons 23
# Window 23 Neurons 23
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 14 Neurons 21
# Training error: 2.433261579426471e-05 Validation error: 2.2662768969894387e-05
# Window 18 Neurons 24
# Window 30 Neurons 21
# Training error: 2.5708923203637823e-05 Validation error: 2.4444112568744458e-05
# Window 26 Neurons 22
# Training error: 2.4938321075751446e-05 Validation error: 0.00010602222755551338
# 7  	51
# Window 19 Neurons 26
# Training error: 2.431516259093769e-05 Validation error: 2.3513644919148646e-05
# Window 19 Neurons 11
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 39 Neurons 20
# Window 11 Neurons 11
# Training error: 2.6394436645205133e-05 Validation error: 7.27695514797233e-05
# Window 37 Neurons 21
# Window 17 Neurons 21
# Training error: 2.324338311154861e-05 Validation error: 2.6959722163155675e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 19 Neurons 24
# Window 14 Neurons 23
# Training error: 2.4559109078836627e-05 Validation error: 2.853080877684988e-05
# Window 18 Neurons 22
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 31 Neurons 24
# Training error: 2.6278577934135683e-05 Validation error: 6.391682109097019e-05
# Window 23 Neurons 30
# Training error: 2.4955099434009753e-05 Validation error: 2.257463893329259e-05
# Window 13 Neurons 21
# Window 58 Neurons 24
# Training error: 2.9718381483689882e-05 Validation error: 0.0002591127995401621
# Window 12 Neurons 23
# Window 24 Neurons 22
# Window 13 Neurons 22
# Training error: 2.3668566427659243e-05 Validation error: 0.00011478848318802193
# Window 15 Neurons 25
# Window 19 Neurons 23
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 17 Neurons 19
# Window 15 Neurons 24
# Window 19 Neurons 24
# Window 19 Neurons 23
# Window 23 Neurons 21
# Window 19 Neurons 24
# Window 18 Neurons 24
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 18 Neurons 24
# Window 21 Neurons 22
# Window 19 Neurons 24
# Window 19 Neurons 23
# Window 19 Neurons 21
# Window 18 Neurons 24
# Window 46 Neurons 24
# Training error: 2.864057751139626e-05 Validation error: 2.5033637939486653e-05
# Window 19 Neurons 24
# Window 15 Neurons 16
# Training error: 2.3828932171454653e-05 Validation error: 4.059014463564381e-05
# Window 17 Neurons 16
# Training error: 2.5728144464665093e-05 Validation error: 2.829873665177729e-05
# Window 20 Neurons 20
# Training error: 2.5582579837646335e-05 Validation error: 4.244361480232328e-05
# Window 29 Neurons 23
# Training error: 2.6455512852407992e-05 Validation error: 3.168080002069473e-05
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 19 Neurons 24
# 8  	52
# Window 20 Neurons 23
# Window 12 Neurons 21
# Training error: 2.3978131139301695e-05 Validation error: 2.0710143871838227e-05
# Window 19 Neurons 20
# Window 33 Neurons 21
# Window 12 Neurons 20
# Training error: 2.3121303456719033e-05 Validation error: 3.3634467399679124e-05
# Window 20 Neurons 24
# Training error: 2.3579686967423186e-05 Validation error: 4.83486546727363e-05
# Window 18 Neurons 24
# Window 18 Neurons 24
# Window 13 Neurons 21
# Window 19 Neurons 17
# Training error: 2.562875670264475e-05 Validation error: 3.342674972373061e-05
# Window 19 Neurons 18
# Training error: 2.4181737899198197e-05 Validation error: 2.16281259781681e-05
# Window 53 Neurons 21
# Training error: 3.1962150387698784e-05 Validation error: 2.803420829877723e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 22
# Window 19 Neurons 22
# Window 19 Neurons 24
# Window 2 Neurons 21
# Training error: 2.2353526219376363e-05 Validation error: 0.000532649748492986
# Window 19 Neurons 23
# Window 19 Neurons 24
# Window 39 Neurons 20
# Window 19 Neurons 23
# Window 18 Neurons 24
# Window 19 Neurons 23
# Window 18 Neurons 24
# Window 18 Neurons 25
# Window 14 Neurons 21
# Window 19 Neurons 24
# Window 18 Neurons 24
# Window 19 Neurons 24
# Window 18 Neurons 24
# Window 19 Neurons 24
# Window 19 Neurons 24
# Window 17 Neurons 24
# Training error: 2.369709181948565e-05 Validation error: 2.741596836131066e-05
# Window 15 Neurons 20
# Window 14 Neurons 26
# Training error: 2.5071152776945382e-05 Validation error: 5.028046507504769e-05
# Window 18 Neurons 21
# Training error: 2.4016468159970827e-05 Validation error: 2.1828149328939617e-05
# Window 13 Neurons 21
# Window 19 Neurons 21
# Window 22 Neurons 24
# Window 18 Neurons 22
# Window 14 Neurons 22
# Window 19 Neurons 23
# Window 19 Neurons 24
# Window 24 Neurons 22
# Window 19 Neurons 24
# 9  	46
# Window 19 Neurons 23
# Window 19 Neurons 23
# Window 18 Neurons 24
# Window 14 Neurons 22
# Window 18 Neurons 22
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 19 Neurons 23
# Window 18 Neurons 26
# Training error: 2.5881387045956217e-05 Validation error: 2.4949884391389787e-05
# Window 14 Neurons 24
# Training error: 2.3358550606644712e-05 Validation error: 2.1144631318747997e-05
# Window 12 Neurons 21
# Window 12 Neurons 23
# Window 19 Neurons 24
# Window 18 Neurons 24
# Window 19 Neurons 23
# Window 12 Neurons 21
# Window 18 Neurons 21
# Window 12 Neurons 20
# Window 20 Neurons 24
# Window 13 Neurons 21
# Window 19 Neurons 27
# Training error: 2.5407845896552317e-05 Validation error: 2.5869190722005442e-05
# Window 19 Neurons 26
# Window 37 Neurons 24
# Training error: 2.701234734558966e-05 Validation error: 2.34470353461802e-05
# Window 13 Neurons 21
# Window 15 Neurons 21
# Window 16 Neurons 23
# Training error: 2.5021761757670902e-05 Validation error: 6.79143049637787e-05
# Window 19 Neurons 21
# Window 12 Neurons 23
# Window 15 Neurons 22
# Window 17 Neurons 23
# Window 19 Neurons 24
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 18 Neurons 24
# Window 19 Neurons 23
# Window 12 Neurons 20
# Window 20 Neurons 24
# Window 16 Neurons 24
# Training error: 2.331312862224877e-05 Validation error: 0.00013541587395593524
# Window 16 Neurons 21
# Training error: 2.3442617020918988e-05 Validation error: 8.577309927204624e-05
# Window 19 Neurons 24
# Window 18 Neurons 24
# Window 18 Neurons 24
# Window 18 Neurons 24
# Window 14 Neurons 21
# Window 18 Neurons 23
# Window 13 Neurons 23
# Window 20 Neurons 21
# Training error: 2.4018483600229956e-05 Validation error: 4.695081224781461e-05
# Window 17 Neurons 27
# Training error: 2.5112327421084046e-05 Validation error: 4.2888870666502044e-05
# Window 19 Neurons 26
# Window 13 Neurons 20
# Training error: 2.269008655275684e-05 Validation error: 2.1639581973431632e-05
# Window 18 Neurons 24
# Window 19 Neurons 18
# 10 	53
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 14 Neurons 22
# Window 18 Neurons 22
# Window 13 Neurons 24
# Training error: 2.3091371986083686e-05 Validation error: 2.0499663150985725e-05
# Window 18 Neurons 21
# Window 13 Neurons 21
# Window 12 Neurons 21
# Window 37 Neurons 24
# Window 12 Neurons 17
# Training error: 2.3176522518042475e-05 Validation error: 2.331977702851873e-05
# Window 18 Neurons 24
# Window 18 Neurons 24
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 20 Neurons 21
# Window 12 Neurons 23
# Window 19 Neurons 23
# Window 19 Neurons 23
# Window 14 Neurons 21
# Window 18 Neurons 21
# Window 14 Neurons 23
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 19 Neurons 24
# Window 13 Neurons 20
# Window 2 Neurons 21
# Window 20 Neurons 23
# Window 12 Neurons 23
# Window 18 Neurons 26
# Window 15 Neurons 24
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 20
# Training error: 2.217321889474988e-05 Validation error: 0.0003913456166628748
# Window 19 Neurons 24
# Window 16 Neurons 23
# Window 36 Neurons 21
# Window 15 Neurons 24
# Window 16 Neurons 20
# Window 13 Neurons 22
# Window 19 Neurons 22
# Window 13 Neurons 21
# Window 18 Neurons 23
# Window 18 Neurons 24
# Window 19 Neurons 21
# Window 30 Neurons 28
# Training error: 2.631860479596071e-05 Validation error: 3.63114922947716e-05
# Window 15 Neurons 22
# Window 17 Neurons 22
# Window 2 Neurons 21
# Window 12 Neurons 21
# 11 	50
# Window 45 Neurons 29
# Training error: 2.742904871411156e-05 Validation error: 4.3762760469689965e-05
# Window 21 Neurons 21
# Window 27 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 20
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 12 Neurons 24
# Training error: 2.3632217562408186e-05 Validation error: 2.0305264115449972e-05
# Window 19 Neurons 21
# Window 13 Neurons 20
# Window 14 Neurons 22
# Window 17 Neurons 23
# Window 19 Neurons 18
# Window 18 Neurons 23
# Window 17 Neurons 24
# Window 14 Neurons 21
# Window 18 Neurons 27
# Training error: 2.5820698283496313e-05 Validation error: 2.9824770535924472e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 18 Neurons 24
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 18 Neurons 18
# Training error: 2.526232674426865e-05 Validation error: 2.1460149582708254e-05
# Window 19 Neurons 31
# Training error: 2.598617720650509e-05 Validation error: 3.3885007724165916e-05
# Window 2 Neurons 23
# Training error: 2.2213143893168308e-05 Validation error: 0.0005353626329451799
# Window 15 Neurons 24
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 17 Neurons 22
# Window 15 Neurons 21
# Window 18 Neurons 21
# Window 14 Neurons 24
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 24
# Window 13 Neurons 20
# Window 15 Neurons 28
# Training error: 2.4137076252372935e-05 Validation error: 4.9587193643674254e-05
# Window 19 Neurons 25
# Training error: 2.461120493535418e-05 Validation error: 2.2537058612215333e-05
# 12 	45
# Window 13 Neurons 22
# Window 18 Neurons 21
# Window 14 Neurons 21
# Window 13 Neurons 16
# Training error: 2.3321723347180523e-05 Validation error: 7.59740942157805e-05
# Window 13 Neurons 21
# Window 19 Neurons 18
# Window 12 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 16 Neurons 21
# Window 17 Neurons 25
# Window 15 Neurons 25
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 40 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 24
# Window 13 Neurons 20
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 30
# Training error: 2.383908758929465e-05 Validation error: 2.317118924111128e-05
# Window 20 Neurons 20
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 24
# Window 18 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 24 Neurons 21
# Training error: 2.4577539079473354e-05 Validation error: 2.1877078324905597e-05
# 13 	42
# Window 17 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 17 Neurons 22
# Window 10 Neurons 21
# Training error: 2.3335896912612952e-05 Validation error: 2.3575952582177706e-05
# Window 17 Neurons 22
# Window 14 Neurons 23
# Window 13 Neurons 21
# Window 2 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 17 Neurons 22
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 20
# Window 13 Neurons 21
# 14 	51
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 19
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 4 Neurons 21
# Training error: 2.2783837266615592e-05 Validation error: 0.0001066117110894993
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 20
# Window 13 Neurons 18
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# 15 	43
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 19
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 21
# Window 20 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 18
# Window 13 Neurons 21
# Window 12 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 21
# ...
# Training error: 2.2607555365539156e-05 Validation error: 2.4478978957631625e-05
# Window 9 Neurons 21
# Training error: 2.2981836082180962e-05 Validation error: 2.1787196601508185e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 64 Neurons 21
# Training error: 3.939727685065009e-05 Validation error: 7.275797543115914e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 15 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 23 Neurons 16
# Training error: 2.4832095732563175e-05 Validation error: 2.306746318936348e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# 17 	43
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 26
# Training error: 2.3929191229399294e-05 Validation error: 2.668213528522756e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 20
# Window 10 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 22
# Window 13 Neurons 21
# Window 2 Neurons 23
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 26
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 27
# Training error: 2.2870826796861365e-05 Validation error: 5.895967478863895e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 21
# Window 2 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 13
# Training error: 2.287781171617098e-05 Validation error: 4.12535373470746e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# 18 	53
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 23
# Window 13 Neurons 21
# Window 4 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 22
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 23
# Window 14 Neurons 19
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 21
# 19 	46
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 25 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 12 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 20
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# 20 	48
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 22
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 18 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 17
# Training error: 2.4739367290749215e-05 Validation error: 4.943268504575826e-05
# Window 2 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 15
# Training error: 2.3852919184719212e-05 Validation error: 2.3682550818193704e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# 21 	47
# Window 13 Neurons 17
# Window 13 Neurons 20
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 25
# Training error: 2.4011984351091087e-05 Validation error: 2.4510978619218804e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 25
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# 22 	52
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 19
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 21
# Window 29 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 17
# Training error: 2.1993068003212102e-05 Validation error: 6.9459892984014e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# 23 	49
# Window 13 Neurons 27
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 15
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 28
# Training error: 2.3072845579008572e-05 Validation error: 3.770853072637692e-05
# Window 20 Neurons 21
# Window 13 Neurons 21
# 24 	39
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 35 Neurons 21
# Training error: 2.6017938580480404e-05 Validation error: 2.2730535420123488e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 23
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 6 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# 25 	50
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 29 Neurons 24
# Training error: 2.40829376707552e-05 Validation error: 2.7282163500785828e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 3 Neurons 21
# Training error: 2.329608287254814e-05 Validation error: 0.0005388162680901587
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 34 Neurons 21
# Training error: 2.527221295167692e-05 Validation error: 2.776362634904217e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 18
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 23
# Window 13 Neurons 21
# Window 2 Neurons 21
# 26 	46
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 21 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 32 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 34 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 15 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# 27 	52
# Window 13 Neurons 21
# Window 13 Neurons 17
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 20
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# 28 	46
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 6 Neurons 21
# Window 13 Neurons 18
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 26
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 2 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 28 Neurons 21
# Window 13 Neurons 21
# Window 18 Neurons 20
# Window 13 Neurons 21
# Window 13 Neurons 21
# 29 	43
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 18
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 22
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 43 Neurons 21
# Training error: 2.8501821361714974e-05 Validation error: 2.511930142645724e-05
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 20
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 18
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 4 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# 30 	52

# %% [markdown]
# #### Show the best solutions

# %%
best_individuals = tools.selBest(population, k=len(population))
# extract best fenotype
best_ann = tuple(
    [int(best_individuals[0][i] * p["range"][i] + p["min"][i])
    for i in range(len(best_individuals[0]))])
best_window_size = best_ann[0]

for chromosome in best_individuals:
    # extract fenotype
    fenotype = tuple(
        [int(chromosome[i] * p["range"][i] + p["min"][i])
        for i in range(len(chromosome))])
    
    for i, j in zip(p["genes"], fenotype):
        print(i, j, "", end="")
    print("")
# Out:
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 21
# Window 13 Neurons 20
# Window 13 Neurons 18
# Window 13 Neurons 18
# Window 43 Neurons 21
# Window 4 Neurons 21
# Window 13 Neurons 22

# %% [markdown]
# #### Train the best individual and test it

# %%
# Here it could create a larger training dataset by setting val_split to 0.0

# set hyperparameters according to best_ann
for i in range(p["ngenes"]):
    p[p["genes"][i]] = best_ann[i]

# Build the ANN
ann, history = create_ann(p, train_scaled, train_scaled)

# Display training and validation losses
print("Training error: {} Validation error: {}".
      format(history.history["loss"][-1], history.history["val_loss"][-1]))
# Out:
# Training error: 2.3396620235871524e-05 Validation error: 1.9962912119808607e-05

# %% [markdown]
# #### Display the best ann

# %%
display_ann(ann, history, best_window_size,
            p["batch_size"], train_scaled, test_scaled)
# Out:
# 129/129 [==============================] - 0s 773us/step - loss: 2.1473e-05
# 32/32 [==============================] - 0s 896us/step - loss: 4.3643e-05
# ANN train: 2.1473293600138277e-05
# ANN test: 4.364298365544528e-05
# R2 score of a trivial predictor on train data:	0.99746553
# R2 score of a trivial predictor on test data:	0.99532218
# MSE of a trivial predictor on train data:	0.00004266
# MSE of a trivial predictor on test data:	0.00008303
# The R2 score on the Train set is:	0.99744765
# The R2 score on the Test set is:	0.99508059
# MSE of the trained ANN on train data:	0.00004295
# MSE of the trained ANN on test data:	0.00008730
