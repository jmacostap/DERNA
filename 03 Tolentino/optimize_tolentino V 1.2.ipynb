# %% [markdown]
# ## Diseño Evolutivo de Redes Neuronales Artificiales
# ## Evolutionary Design of Artificial Neural Networks
# ## DERNA/EDANN
# Parte del código está basado en [Time Series Prediction A Naive Exploration](https://www.researchgate.net/profile/Wilson_Tolentino_Da_Silva2/publication/333982520_Time_Series_Prediction_A_Naive_Exploration/links/5d10ec94299bf1547c7afe08/Time-Series-Prediction-A-Naive-Exploration.pdf)
#
# El objetivo de este programa es optimizar el código publicado (baseline_tolentino_original) usando DERNA.<br>
# En el artículo, Tolentino logra una pérdida de prueba de 0.10234724577159098<br>
# Mi implementación de su programa logra 0.06509439647197723<br>
# El objetivo de este programa es mejorar ese número.<br>
#
# V 1.0 2020-08-11 Reescritura completa de cero de DERNA, ahora usa genes reales, mapeo, alpha blend y mutación por perturbación gausiana.
#
# V 1.1 Implementa tres tipos de genes: enteros, reales y ordinales. Optimiza ventana, neuronas y lote.
#
# V 1.2 Implementa TimeStopping, corrige bug en ordinales. Profundiza la modularización. Optimiza neuronas, ventana y optimizador.
#
# Some code based on [Time Series Prediction A Naive Exploration](https://www.researchgate.net/profile/Wilson_Tolentino_Da_Silva2/publication/333982520_Time_Series_Prediction_A_Naive_Exploration/links/5d10ec94299bf1547c7afe08/Time-Series-Prediction-A-Naive-Exploration.pdf)
#
# The objective of this program is to optimize the published code (baseline_tolentino_original) using EDANN.<br>
# On the paper, Tolentino achieves a Test loss of 0.10234724577159098<br>
# My implementation of the program achieves 0.06509439647197723<br>
# The objective of this program is to outperform those numbers.<br>
#
# V 1.0 2020-08-11 Complete rewrite of EDANN, it now uses real genes, mapping, alpha blend y gaussian perturbation mutation.
#
# V 1.1 Implements three types of genes: integer, real and ordinal. Optimizes neurons, window and batch_size.
#
# V 1.2 Implements TimeStopping, fix bug in ordinals. Furthers modularization. Optimizes neurons, window and optimizer.

# %% [markdown]
# ### Configuración
# ### Setup

# %% [markdown]
# #### Instalación de paquetes
# #### Install packages

# %%
# !pip install -U deap
# !pip install -U tensorflow-addons
# Out:
# Collecting deap
#   Downloading https://files.pythonhosted.org/packages/99/d1/803c7a387d8a7e6866160b1541307f88d534da4291572fb32f69d2548afb/deap-1.3.1-cp37-cp37m-manylinux2010_x86_64.whl (157kB)
#      |████████████████████████████████| 163kB 8.5MB/s
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from deap) (1.19.5)
# Installing collected packages: deap
# Successfully installed deap-1.3.1
# Collecting tensorflow-addons
#   Downloading https://files.pythonhosted.org/packages/74/e3/56d2fe76f0bb7c88ed9b2a6a557e25e83e252aec08f13de34369cd850a0b/tensorflow_addons-0.12.1-cp37-cp37m-manylinux2010_x86_64.whl (703kB)
#      |████████████████████████████████| 706kB 9.0MB/s
# Requirement already satisfied, skipping upgrade: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.12.1

# %% [markdown]
# ##### Importar librerías y funciones
# ##### Import libraries and functions

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

import sklearn.preprocessing as skp
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

import tensorflow_addons as tfa

from deap import base, creator, tools, algorithms

# %% [markdown]
# #### Hiperparámetros
# #### Hyperparameters

# %%
p = {
     # RNA/ANN
     "Window": 33,  # tamaño de ventana para la trasposición
     # window size for transposition
     "Neurons": 20,  # neuronas escondidas/hidden layer neurons
     "activation": "relu",  # de la capa escondida/of the hidden layer
     # puede ser/could be: relu, sigmoid, softmax, softplus, softsign, tanh,
     # selu, elu, exponential, or linear
     "output_activation": "linear",  # de la capa de salida/of the output layer
     
     # entrenamiento/training
     "loss": "mse",  # puede ser/could be: mse, mae, msle, cs, huber,
     # or logcosh
     "optimizer": "adamax",  # puede ser/could be: sgd, rmsprop, adam,
     # adadelta, adagrad, adamax, nadam, or ftrl
     # o una instancia de una clase con parámetros como
     # or a class instance with sub-parameters like
     # tf.keras.optimizers.SGD(
     #    learning_rate=0.3,
     #    momentum=0.2,
     #    nesterov=False),
     "test_split" : 0.20,  # 20% para prueba/for testing
     "val_split" : 0.20,  # 20% para validación/for validation
     "seconds" : 5,  # limita el tiempo de entrenamiento/limit training time
     "epochs": 100,  # épocas de entrenamiento durante la optimización
     # training epochs during optimization
     "batch_size": 30,  # tamaño de los lotes de entrenamiento
     # training batches size
     "shuffle": True,  # mezclar los datos de entrenamiento/the training data
     "verbose": 0,  # entrenamiento verboso, 1 es muy abundante, mejor 2
     # verbose training, 1 is too chatty, 2 may be convenient
     
     # AG/GA
     "population" : 30,  # número de individuos en la población
     # debe escogerse basado en el tamaño del espacio a optimizar
     # entre más alto mejor cerca de sqrt(tamaño del espacio)
     # number of individuals in population
     # should be chosen based on the size of the optimization space
     # (better high around sqrt(space size))
     "ngen" : 15,  # número de generaciones (suficiente para que converga)
     # DERNA no hace evaluaciones redundantes, por lo que no es peligroso
     # un número alto
     # number of generations (just high enough)
     # EDANN does no redundant evaluations so a high value is not a problem
     "alpha" : 0.2,  # sobrepeso del alpha blend (no debe ser muy alto)
     # alpha blend oversize (better not too high)
     "sigma": 0.1,  # para la mutación gausiana
     # for gaussian mutation
     "indpb": 0.2,  # para la mutación gausiana
     # for gaussian mutation
     "tournsize" : 3,  # tamaño del torneo
     # tournament size
     "cxpb" : 0.6,  # probabilidad de cruce (mejor alta)
     # crossover probability (better high)
     "mutpb" : 0.01,  # probabilidad de mutación (mejor baja)
     # mutation probability (better low)

     # optimizador/optimizer
     "ngenes" : 3,  # número de genes en el cromosoma
     # number of genes in a chromosome
     "genes" : ("Window", "Neurons", "optimizer"),
     "min" : (1, 1, 0),  # mínimo valor de cada gen
     # minimun value of each gene
     "range" : (200, 30, 5),  # rango de valores de cada gen
     # range of values of each gene
     "type" : ("I", "I", "O"),  # tipo de cada gen, I entero, Real, Ordinal
     # type of gene Integer, Real, Ordinal
     "ordinals" : ([], [], ["adamax", "adam", "nadam", "sgd", "adagrad"]),
     # lista de valores para los genes ordinales
     # list of values for ordinal genes
    }

# %% [markdown]
# ### Inicialización
# ### Initializing

# %% [markdown]
# #### Leer los datos del repositorio
# #### Read data from repository

# %%
# copiar el archivo del repositorio
# copy file from repository
path_to_downloaded_file = tf.keras.utils.get_file(
    "baseline_tolentino.csv",
    "https://raw.githubusercontent.com/jmacostap/webstore/master/"+
    "baseline_tolentino.csv",
    cache_dir="/content",
    )
# cargar los datos en un dataframe Pandas
# load data into a Pandas dataframe
df = pd.read_csv(path_to_downloaded_file)
print(len(df), "lines read")
# Out:
# Downloading data from https://raw.githubusercontent.com/jmacostap/webstore/master/baseline_tolentino.csv
# 335872/328946 [==============================] - 0s 0us/step
# 4829 lines read

# %% [markdown]
# #### Agregar nuevas columnas y eliminar las que no se van a usar
# #### Add new columns and drop unused ones

# %%
df.drop(["Date", "Open", "High", "Low", "Volume"], axis=1, inplace=True)

# %% [markdown]
# #### Separar los datos en entrenamiento y prueba
# #### Split data into train and test sets

# %%
# MinMaxScaler requiere arreglos Numpy bidimensionales
# MinMaxScaler requires 2D Numpy Arrays
test_split = int(len(df) * (1.0 - p["test_split"]))
train = df.iloc[:test_split].values.reshape(-1,1)
test = df.iloc[test_split:].values.reshape(-1,1)

# %% [markdown]
# #### Escalar los datos a [0, 1]
# #### Scale data to [0, 1]

# %%
scaler = skp.MinMaxScaler(feature_range=(0, 1))
# se escala solo con los datos de entrenamiento para evitar fuga de datos
# it should not fit using both arrays, use only train to avoid data leak
scaler.fit(train)
train_scaled = scaler.transform(train).flat
test_scaled = scaler.transform(test).flat

# %% [markdown]
# #### Definición de funciones auxiliares
# #### Auxiliary functions definition

# %% [markdown]
# ##### Covertir la serie de tiempo en ventanas deslizantes
# ##### Convert the time series into sliding windows

# %%
def prepare_time_series(time_series, targets, window):
    """Prepara la serie de tiempo para Keras
    como tf.keras.preprocessing.sequence.TimeseriesGenerator
    pero sin crear los lotes
    En el caso típico time_series y targets son el mismo arreglo

    Prepare time series and targets for Keras
    like tf.keras.preprocessing.sequence.TimeseriesGenerator
    without the batches
    In the typical case time_series and targets are the same array

    Args:
    time_series: flat array-like: of values of the time series
    targets: flat array-like: of target values
    X[0] = time_series[0:window]
    Y[0] = targets[window]
    
    Returns:
    X: 2D ndarray: of dataset_length vectors of window elements
    Y: 1D ndarray: of targets[window:]
    """

    dataset_length = len(time_series) - window
    X = np.empty((dataset_length, window))
    Y = np.empty((dataset_length, 1))
    for i in range(dataset_length):
        X[i, :] = time_series[i:(i + window)]
        Y[i, 0] = targets[i + window]
    return X, Y

# %% [markdown]
# ##### Crear, entrenar y probar la RNA
# ##### Create train and test an ANN

# %%
def create_ann(p, train_data, targets):
    """Crea una RNA con los parámetros de p y la entrena con train_data
    Create an ANN with the parameters on p and train it with train_data

    Args:
    p: dict: of hyperparameters
    train_data: flat array-like: of training data
    targets: flat array-like: of targets
    
    Returns:
    ann: keras.model: the trained neural network
    history: keras.history: the training history
    """

    X_train, y_train = prepare_time_series(
        train_data, targets, p["Window"])

    # asegura reproducibilidad y consistencia de los fenotipos
    # ensure reproducibility and consistency across fenotypes
    tf.random.set_seed(31415926)  # Keras

    ann = Sequential([Dense(units=p["Neurons"],
                            input_dim=p["Window"],
                            activation=p["activation"]),
                      Dense(units=1,
                            activation=p["output_activation"])])

    ann.compile(loss=p["loss"], optimizer=p["optimizer"])

    time_stopping_callback = tfa.callbacks.TimeStopping(
        seconds=p["seconds"], verbose=1)

    history = ann.fit(x=X_train,
                      y=y_train,
                      epochs=p["epochs"],
                      batch_size=p["batch_size"],
                      verbose=p["verbose"],
                      callbacks=[time_stopping_callback],
                      validation_split=p["val_split"],
                      shuffle=p["shuffle"])
    
    return ann, history

# %% [markdown]
# ##### Crear y evaluar la RNA descrita por un cromosoma
# ##### Create and evaluate the ANN described by a chromosome

# %%
def extract_fenotype(chromosome, p):
    """Construye el fenotipo correspondiente a un genotipo/cromosoma
    Build the corresponding fenotype for a genotype/chromosome

    Args:
    chromosome: list: of genes. Each gene is a float that describes an
                ANN feature
    p: dict: of hyperparameters

    Returns:
    fenotype: tuple: of hyperparámeters
    """

    fenotype_list=[]
    for i in range(p["ngenes"]):
        j = chromosome[i] * p["range"][i] + p["min"][i]
        if p["type"][i] == "I":
            fenotype_list.append(int(j))
        elif p["type"][i] == "R":
            fenotype_list.append(j)
        else:
            fenotype_list.append(p["ordinals"][i][int(j)])

    return tuple(fenotype_list)


def set_fenotype(fenotype, p):
    """Fija los hiperparámetros en p según un fenotipo
    Set hyperparameters in p as per a fenotype

    Args:
    fenotype: tuple: of parameter values
    p: dict: of hiperparámeters

    Returns:
    p values set as per fenotype
    """

    for i in range(p["ngenes"]):
        p[p["genes"][i]] = fenotype[i]


def print_fenotype(fenotype, p):
    """Muestra los valores de un fenotipo
    Pretty-print the values of a fenotype

    Args:
    fenotype: tuple: of hiperparámeters
    p: dict: of hiperparámeters

    Returns:
    Nothing
    """

    for i, j in zip(p["genes"], fenotype):
        print(i, j, "", end="")
    print("")


def evaluate_chromosome(chromosome, p, train_data, targets, seen_fenotypes):
    """Construir, entrenar y evaluar la RNA descrita por un cromosoma
    - Extraer el fenotipo del cromosoma
    - Si ya ha sido evaluado, devolver la pérdida inmediatamente
    - si no, crear la RNA, entrenarla y evaluarla
    - finalmente guardar los errores de entrenamiento y validación

    Build, train and evaluate the ANN represented by a chromosome
    - Extract the fenotype from the chromosome
    - If it has been previously evaluated return the loss immediately
    - otherwise create train and evaluate the ann
    - finally save the training and validation loss

    Args:
    chromosome: list: of genes. Each gene is a float that describes an
                ANN feature
    p: dict: of hyperparameters
    train_data: flat array-like: data for training
    targets: flat array-like: targets for training
    seen_fenotypes: dict: evaluated fenotypes and their losses

    Returns:
    (float,): Validation loss
    """

    fenotype = extract_fenotype(chromosome, p)
    set_fenotype(fenotype, p)
    print_fenotype(fenotype, p)

    # evita evaluar de nuevo el mismo fenotipo
    # avoid evaluating the same fenotype twice
    if fenotype in seen_fenotypes:
        return seen_fenotypes[fenotype][0],  # loss=0 val_loss=1

    # construye la RNA
    # build the ANN
    model, history = create_ann(p, train_scaled, train_scaled)

    # extrae y despliega los errores
    # extract and display training and validation loss
    val_loss = history.history["val_loss"][-1]
    loss = history.history["loss"][-1]
    print("Training error: {} Validation error: {}".format(loss, val_loss))

    # finalmente guarda los errores
    # finally, save the losses
    seen_fenotypes[fenotype] = val_loss, loss
    return val_loss, # puede ser/can be loss o/or val_loss

# %% [markdown]
# #### Crea la definición de ajuste
# #### Create the fitness definition

# %%
# normalmente fitness trata de maximizar, se usa peso negativo para maximizar
# fitness normally tries to maximize we use negative weight to minimize
#creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# %% [markdown]
# #### Definir el resto de los operadores genéticos en el toolbox
# #### Define the rest of the genetic operators on the toolbox

# %%
toolbox = base.Toolbox()
toolbox.register("attr_float", random.random)
toolbox.register("individual", tools.initRepeat, creator.Individual,
                 toolbox.attr_float, n=p["ngenes"])
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

def checkBounds(min, max):
    """Decorador para ajustar el valor del gen si se sale de rango
    Decorator to adjust the gene value in case it is out of bounds

    Args:
    min: minimum value
    max: maximum value

    Returns:
    The function that checks bounds to decorate mate or mutate on the toolbox
    """

    def decorator(func):
        def wrapper(*args, **kargs):
            offspring = func(*args, **kargs)
            for child in offspring:
                for i in range(len(child)):
                    if child[i] > max:
                        child[i] = max
                    elif child[i] < min:
                        child[i] = min
            return offspring
        return wrapper
    return decorator


# mate by Alpha Blend
toolbox.register("mate", tools.cxBlend, alpha=p["alpha"])
# stay within [0,1)
toolbox.decorate("mate", checkBounds(0.0, 0.9999999999999999))
# mutate by gaussian perturbation
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=p["sigma"],
                 indpb=p["indpb"])
# stay within [0,1)
toolbox.decorate("mutate", checkBounds(0.0, 0.9999999999999999))
toolbox.register("select", tools.selTournament, tournsize=p["tournsize"])
# initialize seen list to avoid multiple evaluations
seen_fenotypes = {}
toolbox.register("evaluate", evaluate_chromosome, p=p, train_data=train_scaled,
                 targets=train_scaled, seen_fenotypes=seen_fenotypes)

# %% [markdown]
# ### El Algoritmo Genético
# ### The Genetic Algorithm

# %% [markdown]
# ### Ejecuta el AG
# #### Run the GA

# %%
# siembra el generador aleatorio para asegurar reproducibilidad
# seed the random generator to ensure reproducibility
random.seed(31416) # DEAP/EDANN

seen_fenotypes = {}

population = toolbox.population(n=p["population"])
algorithms.eaSimple(population, toolbox, cxpb=p["cxpb"],
                           mutpb=p["mutpb"], ngen=p["ngen"], verbose=True)
# Out:
# Window 102 Neurons 30 optimizer sgd
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.0011649951338768005 Validation error: 0.0017393563175573945
# Window 173 Neurons 14 optimizer sgd
# Timed stopping at epoch 48 after training for 0:00:05
# Training error: 0.001761311898007989 Validation error: 0.003255706513300538
# Window 106 Neurons 21 optimizer adamax
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.000825443072244525 Validation error: 0.0009296225616708398
# Window 92 Neurons 26 optimizer sgd
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.0009155642474070191 Validation error: 0.0010989910224452615
# Window 48 Neurons 18 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00028954914887435734 Validation error: 0.00021646688401233405
# Window 191 Neurons 17 optimizer adamax
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0005513891810551286 Validation error: 0.0008852446335367858
# Window 198 Neurons 16 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0004917670739814639 Validation error: 0.0006074976408854127
# Window 166 Neurons 19 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0008320471388287842 Validation error: 0.004824398551136255
# Window 57 Neurons 1 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00068259536055848 Validation error: 0.0007671040948480368
# Window 48 Neurons 24 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00021999537420924753 Validation error: 0.00017744131037034094
# Window 196 Neurons 2 optimizer sgd
# Timed stopping at epoch 48 after training for 0:00:05
# Training error: 0.013193472288548946 Validation error: 0.17242789268493652
# Window 192 Neurons 18 optimizer adamax
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0004376209690235555 Validation error: 0.00046338560059666634
# Window 91 Neurons 3 optimizer adagrad
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.09850983321666718 Validation error: 0.4755110740661621
# Window 50 Neurons 28 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00031585872056894004 Validation error: 0.00025839731097221375
# Window 131 Neurons 7 optimizer adamax
# Timed stopping at epoch 48 after training for 0:00:05
# Training error: 0.00041767203947529197 Validation error: 0.0006408526096493006
# Window 114 Neurons 3 optimizer sgd
# Timed stopping at epoch 49 after training for 0:00:05
# Training error: 0.015813305974006653 Validation error: 0.1760614663362503
# Window 185 Neurons 25 optimizer nadam
# Timed stopping at epoch 37 after training for 0:00:05
# Training error: 0.0007386536453850567 Validation error: 0.0019066117238253355
# Window 138 Neurons 30 optimizer adagrad
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.0039415182545781136 Validation error: 0.0068576461635529995
# Window 108 Neurons 22 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00042427919106557965 Validation error: 0.0003122517082374543
# Window 113 Neurons 24 optimizer adagrad
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.003923737443983555 Validation error: 0.005730765871703625
# Window 127 Neurons 23 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0006872068624943495 Validation error: 0.001674743602052331
# Window 17 Neurons 8 optimizer adam
# Timed stopping at epoch 48 after training for 0:00:05
# Training error: 0.00017953358474187553 Validation error: 0.0001505416294094175
# Window 131 Neurons 12 optimizer adagrad
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.002450645435601473 Validation error: 0.003064206335693598
# Window 68 Neurons 19 optimizer adagrad
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0012884397292509675 Validation error: 0.002597380429506302
# Window 100 Neurons 7 optimizer adamax
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0007339421426877379 Validation error: 0.0008562972070649266
# Window 123 Neurons 23 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0005520745762623847 Validation error: 0.0007762638852000237
# Window 156 Neurons 10 optimizer sgd
# Timed stopping at epoch 48 after training for 0:00:05
# Training error: 0.0009018236305564642 Validation error: 0.002029040362685919
# Window 132 Neurons 12 optimizer nadam
# Timed stopping at epoch 41 after training for 0:00:05
# Training error: 0.0007291896617971361 Validation error: 0.008077702485024929
# Window 142 Neurons 17 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0005700223846361041 Validation error: 0.0007604294223710895
# Window 113 Neurons 26 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0005931688356213272 Validation error: 0.0034330810885876417
# gen	nevals
# 0  	30
# Window 73 Neurons 22 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00038315984420478344 Validation error: 0.00034940559999085963
# Window 173 Neurons 18 optimizer nadam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.00073926558252424 Validation error: 0.0004890774725936353
# Window 191 Neurons 16 optimizer adamax
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.000860868371091783 Validation error: 0.00115423824172467
# Window 192 Neurons 18 optimizer adamax
# Window 125 Neurons 8 optimizer adamax
# Timed stopping at epoch 39 after training for 0:00:05
# Training error: 0.00041162956040352583 Validation error: 0.0005714906728826463
# Window 23 Neurons 7 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0005469251773320138 Validation error: 0.0005011598113924265
# Window 127 Neurons 23 optimizer nadam
# Window 43 Neurons 18 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00022060958144720644 Validation error: 0.00016731556388549507
# Window 49 Neurons 25 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00018959748558700085 Validation error: 0.00014895305503159761
# Window 49 Neurons 27 optimizer nadam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.00039061083225533366 Validation error: 0.00043336348608136177
# Window 169 Neurons 23 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0005095006199553609 Validation error: 0.0009388099424540997
# Window 146 Neurons 18 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0002745371311903 Validation error: 0.00031862055766396224
# Window 94 Neurons 24 optimizer sgd
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0014053264167159796 Validation error: 0.002399153308942914
# Window 105 Neurons 24 optimizer sgd
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0009009394561871886 Validation error: 0.0021252676378935575
# Window 160 Neurons 9 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0005169816431589425 Validation error: 0.0007572203176096082
# Window 54 Neurons 14 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0003552685957401991 Validation error: 0.00034435809357091784
# Window 192 Neurons 18 optimizer adamax
# Window 192 Neurons 18 optimizer adamax
# Window 199 Neurons 14 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.0006426778854802251 Validation error: 0.002166363876312971
# Window 43 Neurons 12 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0003053504042327404 Validation error: 0.0003670969745144248
# 1  	20
# Window 31 Neurons 10 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00029941953835077584 Validation error: 0.00023821003560442477
# Window 46 Neurons 11 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0003994217258878052 Validation error: 0.00035252224188297987
# Window 49 Neurons 11 optimizer adam
# Timed stopping at epoch 41 after training for 0:00:05
# Training error: 0.0002204310876550153 Validation error: 0.00023321405751630664
# Window 49 Neurons 15 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00029186703613959253 Validation error: 0.00029170443303883076
# Window 48 Neurons 18 optimizer adam
# Window 48 Neurons 18 optimizer adam
# Window 55 Neurons 1 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0007910786662250757 Validation error: 0.0007423967472277582
# Window 56 Neurons 15 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0002398090873612091 Validation error: 0.00019050287664867938
# Window 169 Neurons 22 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0002971431822516024 Validation error: 0.0003480282612144947
# Window 72 Neurons 20 optimizer adamax
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.0006933410186320543 Validation error: 0.0005881038960069418
# Window 44 Neurons 8 optimizer adam
# Timed stopping at epoch 48 after training for 0:00:05
# Training error: 0.0003983703791163862 Validation error: 0.00035700525040738285
# Window 20 Neurons 24 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00019072012219112366 Validation error: 0.00018487761553842574
# Window 30 Neurons 22 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00020806181419175118 Validation error: 0.00015739581431262195
# Window 35 Neurons 9 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0002051244373433292 Validation error: 0.00017324085638392717
# Window 47 Neurons 18 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00021183834178373218 Validation error: 0.00021433860820252448
# Window 193 Neurons 18 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0003042723110411316 Validation error: 0.0004631785850506276
# Window 16 Neurons 6 optimizer adam
# Timed stopping at epoch 48 after training for 0:00:05
# Training error: 0.00023241704911924899 Validation error: 0.0002497909590601921
# Window 44 Neurons 20 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00019420871103648096 Validation error: 0.00018602849741000682
# Window 60 Neurons 7 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00032030942384153605 Validation error: 0.0002976359974127263
# Window 103 Neurons 19 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00024930157815106213 Validation error: 0.0004920696374028921
# Window 155 Neurons 12 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0002996134280692786 Validation error: 0.0002671254624146968
# Window 59 Neurons 11 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.000253673322731629 Validation error: 0.00022097838518675417
# 2  	22
# Window 21 Neurons 9 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.000180033064680174 Validation error: 0.0002259827742818743
# Window 52 Neurons 14 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00023558258544653654 Validation error: 0.00023982475977391005
# Window 33 Neurons 8 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00030251729185692966 Validation error: 0.0003875911352224648
# Window 39 Neurons 14 optimizer adam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.0002333178126718849 Validation error: 0.00027757580392062664
# Window 28 Neurons 13 optimizer nadam
# Timed stopping at epoch 38 after training for 0:00:05
# Training error: 0.00029745500069111586 Validation error: 0.000230336474487558
# Window 19 Neurons 17 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00028403420583344996 Validation error: 0.0003374046937096864
# Window 41 Neurons 21 optimizer adam
# Timed stopping at epoch 41 after training for 0:00:05
# Training error: 0.00022694900690112263 Validation error: 0.0001754956756485626
# Window 62 Neurons 10 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00035397009924054146 Validation error: 0.00035423217923380435
# Window 178 Neurons 7 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00025569371064193547 Validation error: 0.00028829119401052594
# Window 1 Neurons 13 optimizer adam
# Timed stopping at epoch 49 after training for 0:00:05
# Training error: 0.00011069091851823032 Validation error: 0.000511775491759181
# Window 57 Neurons 24 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.00033226778032258153 Validation error: 0.0003816511598415673
# Window 19 Neurons 14 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.0002183334290748462 Validation error: 0.00019459897885099053
# Window 55 Neurons 18 optimizer adam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.0002983666490763426 Validation error: 0.0003373783256392926
# Window 49 Neurons 15 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00022415629064198583 Validation error: 0.0001868519902927801
# Window 1 Neurons 18 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00011071648623328656 Validation error: 0.0006204789387993515
# Window 196 Neurons 12 optimizer adam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.00035314401611685753 Validation error: 0.00029235065449029207
# Window 17 Neurons 9 optimizer nadam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.00019916064047720283 Validation error: 0.0002974852977786213
# Window 20 Neurons 22 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0002065657899947837 Validation error: 0.00025313999503850937
# 3  	18
# Window 39 Neurons 19 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0002645491622388363 Validation error: 0.000217159089515917
# Window 58 Neurons 17 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0003450495714787394 Validation error: 0.0002944856823887676
# Window 49 Neurons 17 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0002025893918471411 Validation error: 0.0001488670677645132
# Window 48 Neurons 16 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00038240893627516925 Validation error: 0.00036836546496488154
# Window 48 Neurons 18 optimizer adam
# Window 48 Neurons 18 optimizer adam
# Window 20 Neurons 22 optimizer nadam
# Window 48 Neurons 16 optimizer adam
# Window 48 Neurons 17 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00025117790210060775 Validation error: 0.000264165602857247
# Window 47 Neurons 21 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00029365497175604105 Validation error: 0.0004001469351351261
# Window 42 Neurons 18 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00021600913896691054 Validation error: 0.00029593019280582666
# Window 20 Neurons 20 optimizer nadam
# Timed stopping at epoch 41 after training for 0:00:05
# Training error: 0.0005094949738122523 Validation error: 0.0004857603635173291
# Window 48 Neurons 21 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00029229451320134103 Validation error: 0.0004775472334586084
# Window 18 Neurons 14 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00020021470845676959 Validation error: 0.00024318526266142726
# Window 50 Neurons 15 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.00038426375249400735 Validation error: 0.0007582048419862986
# Window 35 Neurons 22 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0002426267456030473 Validation error: 0.00044792742119170725
# Window 27 Neurons 22 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0003415185783524066 Validation error: 0.00029285060008987784
# 4  	17
# Window 17 Neurons 20 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.0002233119448646903 Validation error: 0.00024513527750968933
# Window 44 Neurons 24 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0003462641325313598 Validation error: 0.00028608666616491973
# Window 20 Neurons 24 optimizer nadam
# Window 20 Neurons 24 optimizer nadam
# Window 25 Neurons 21 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00020899013907182962 Validation error: 0.0002328249393031001
# Window 34 Neurons 21 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00024123926414176822 Validation error: 0.0001963023387361318
# Window 20 Neurons 24 optimizer nadam
# Window 20 Neurons 24 optimizer nadam
# Window 29 Neurons 24 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.00026256038108840585 Validation error: 0.00018152159464079887
# Window 40 Neurons 16 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.0006646474357694387 Validation error: 0.0005707728560082614
# Window 20 Neurons 22 optimizer nadam
# Window 44 Neurons 21 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0002413109759800136 Validation error: 0.00021226132230367512
# Window 21 Neurons 12 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00021525136253330857 Validation error: 0.00019017374143004417
# Window 19 Neurons 12 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0003151848795823753 Validation error: 0.00026428987621329725
# 5  	14
# Window 48 Neurons 21 optimizer adam
# Window 42 Neurons 16 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0005285533261485398 Validation error: 0.0007837120210751891
# Window 43 Neurons 24 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0005392081220634282 Validation error: 0.00025050327531062067
# Window 19 Neurons 21 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00014765560626983643 Validation error: 0.00012812983186449856
# Window 44 Neurons 24 optimizer nadam
# Window 18 Neurons 20 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00029921511304564774 Validation error: 0.0003079586895182729
# Window 40 Neurons 23 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0002541110443416983 Validation error: 0.00037649364094249904
# Window 24 Neurons 20 optimizer nadam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.0001622066629352048 Validation error: 0.00015333735791500658
# Window 41 Neurons 21 optimizer adam
# Window 41 Neurons 21 optimizer adam
# Window 48 Neurons 22 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00025482027558609843 Validation error: 0.00032189401099458337
# Window 15 Neurons 14 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00019213848281651735 Validation error: 0.00014957903476897627
# Window 20 Neurons 24 optimizer nadam
# Window 20 Neurons 24 optimizer nadam
# 6  	14
# Window 44 Neurons 22 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00023676504497416317 Validation error: 0.00029545259894803166
# Window 46 Neurons 16 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00025164432008750737 Validation error: 0.00020984919683542103
# Window 41 Neurons 18 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00027837196830660105 Validation error: 0.00022610434098169208
# Window 49 Neurons 19 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00031524559017270803 Validation error: 0.0002709357941057533
# Window 49 Neurons 17 optimizer adam
# Window 49 Neurons 17 optimizer adam
# Window 16 Neurons 22 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00013831823889631778 Validation error: 0.00012564958888106048
# Window 41 Neurons 13 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.000335869932314381 Validation error: 0.0004067397676408291
# Window 25 Neurons 21 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0001813326234696433 Validation error: 0.00024116357963066548
# Window 35 Neurons 21 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00016320613212883472 Validation error: 0.00012900221918243915
# Window 41 Neurons 21 optimizer adam
# Window 41 Neurons 21 optimizer adam
# Window 34 Neurons 24 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00016398300067521632 Validation error: 0.0001544281403766945
# Window 44 Neurons 17 optimizer nadam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.0002333832235308364 Validation error: 0.00017370778368785977
# Window 19 Neurons 21 optimizer nadam
# Timed stopping at epoch 41 after training for 0:00:05
# Training error: 0.0002347181289223954 Validation error: 0.0004478718328755349
# Window 20 Neurons 23 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00023044986301101744 Validation error: 0.00024511918309144676
# Window 24 Neurons 16 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0002022325061261654 Validation error: 0.00022843129409011453
# Window 49 Neurons 20 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00040317027014680207 Validation error: 0.0003748227609321475
# Window 41 Neurons 21 optimizer adam
# Window 41 Neurons 21 optimizer adam
# Window 35 Neurons 22 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.00026783382054418325 Validation error: 0.00034384679747745395
# Window 36 Neurons 23 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00024383966228924692 Validation error: 0.0001854838919825852
# 7  	22
# Window 40 Neurons 18 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.0004191418120171875 Validation error: 0.0003123490896541625
# Window 20 Neurons 21 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00017125748854596168 Validation error: 0.0001379953173454851
# Window 41 Neurons 21 optimizer adam
# Window 41 Neurons 21 optimizer adam
# Window 26 Neurons 21 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00019150387379340827 Validation error: 0.000171337160281837
# Window 14 Neurons 21 optimizer nadam
# Timed stopping at epoch 41 after training for 0:00:05
# Training error: 0.000183870128239505 Validation error: 0.0002530205820221454
# Window 35 Neurons 16 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00041096642962656915 Validation error: 0.0004475915338844061
# Window 48 Neurons 24 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0001892765867523849 Validation error: 0.00015943891776259989
# Window 23 Neurons 21 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0003046216443181038 Validation error: 0.0002589000796433538
# Window 42 Neurons 16 optimizer adam
# Window 46 Neurons 17 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00028141034999862313 Validation error: 0.0005484900902956724
# Window 47 Neurons 17 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0002298556501045823 Validation error: 0.00025757375988177955
# Window 26 Neurons 22 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.0002020523534156382 Validation error: 0.00033392952173016965
# Window 33 Neurons 22 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00021925821783952415 Validation error: 0.0001763088657753542
# Window 28 Neurons 20 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.0002034850331256166 Validation error: 0.0002935694355983287
# Window 31 Neurons 21 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0003111606347374618 Validation error: 0.0006828946643508971
# Window 43 Neurons 20 optimizer nadam
# Timed stopping at epoch 41 after training for 0:00:05
# Training error: 0.00034006606438197196 Validation error: 0.00028369127539917827
# Window 18 Neurons 22 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.00021694376482628286 Validation error: 0.00019467745732981712
# 8  	18
# Window 24 Neurons 18 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0003058878646697849 Validation error: 0.00031117661274038255
# Window 45 Neurons 22 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00024779775412753224 Validation error: 0.0006362151470966637
# Window 47 Neurons 19 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00032261715386994183 Validation error: 0.000385418301448226
# Window 35 Neurons 21 optimizer adam
# Window 26 Neurons 21 optimizer adam
# Window 43 Neurons 19 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00032312687835656106 Validation error: 0.0003456567064858973
# Window 48 Neurons 23 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00020634014799725264 Validation error: 0.0001778400328475982
# Window 34 Neurons 16 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00044770215754397213 Validation error: 0.0005990351201035082
# Window 39 Neurons 21 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00044634094228968024 Validation error: 0.0003737848892342299
# Window 44 Neurons 21 optimizer adam
# Window 45 Neurons 24 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00022206761059351265 Validation error: 0.00017789991397876292
# Window 41 Neurons 17 optimizer nadam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00026653954409994185 Validation error: 0.0002531672071199864
# Window 44 Neurons 21 optimizer adam
# Window 24 Neurons 20 optimizer nadam
# Window 24 Neurons 20 optimizer nadam
# Window 45 Neurons 17 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0002523246221244335 Validation error: 0.000466248020529747
# Window 47 Neurons 17 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00025648390874266624 Validation error: 0.00022701047419104725
# Window 48 Neurons 20 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.0004394618154037744 Validation error: 0.0005300788907334208
# Window 49 Neurons 21 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00023639675055164844 Validation error: 0.00040475220885127783
# Window 49 Neurons 18 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00021728278079535812 Validation error: 0.0001865644589997828
# Window 41 Neurons 19 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00024659879272803664 Validation error: 0.00023637998674530536
# Window 23 Neurons 21 optimizer adam
# Window 22 Neurons 21 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00021132799156475812 Validation error: 0.0002076218370348215
# 9  	23
# Window 24 Neurons 22 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00021845765877515078 Validation error: 0.00019200878159608692
# Window 47 Neurons 23 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00028094384470023215 Validation error: 0.00027420007972978055
# Window 27 Neurons 18 optimizer adam
# Timed stopping at epoch 47 after training for 0:00:05
# Training error: 0.00019240082474425435 Validation error: 0.00023098662495613098
# Window 46 Neurons 20 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.0004776745045091957 Validation error: 0.0009265471016988158
# Window 46 Neurons 21 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00025407702196389437 Validation error: 0.00031191177549771965
# Window 33 Neurons 21 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.0002330793795408681 Validation error: 0.0002615978301037103
# Window 36 Neurons 17 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00022200931562110782 Validation error: 0.00020076848159078509
# Window 42 Neurons 21 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00020287763618398458 Validation error: 0.00018232232832815498
# Window 21 Neurons 18 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0002969525521621108 Validation error: 0.0002934104995802045
# Window 52 Neurons 19 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.00032122168340720236 Validation error: 0.0005175024853087962
# Window 45 Neurons 21 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00021306636335793883 Validation error: 0.0002626226923894137
# Window 38 Neurons 18 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00027052656514570117 Validation error: 0.0002442833792883903
# Window 43 Neurons 20 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00024184126232285053 Validation error: 0.00022695958614349365
# Window 41 Neurons 19 optimizer adam
# Window 44 Neurons 18 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00045771972509101033 Validation error: 0.0005418579676188529
# Window 45 Neurons 24 optimizer adam
# Window 24 Neurons 21 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00030438287649303675 Validation error: 0.0004314434772823006
# Window 23 Neurons 21 optimizer nadam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.000307003763737157 Validation error: 0.00031431621755473316
# 10 	18
# Window 51 Neurons 17 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00027524458710104227 Validation error: 0.0003769352042581886
# Window 32 Neurons 20 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00018636589811649173 Validation error: 0.000218724220758304
# Window 31 Neurons 23 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00021347578149288893 Validation error: 0.00022103317314758897
# Window 47 Neurons 21 optimizer adam
# Window 45 Neurons 17 optimizer adam
# Window 40 Neurons 17 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00022593130415771157 Validation error: 0.00023100606631487608
# Window 44 Neurons 24 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0002649943926371634 Validation error: 0.0005075143999420106
# Window 39 Neurons 21 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00021162832854315639 Validation error: 0.00019698514370247722
# Window 24 Neurons 20 optimizer nadam
# Window 24 Neurons 22 optimizer nadam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.00025362512678839266 Validation error: 0.00021929464128334075
# Window 27 Neurons 20 optimizer adam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.0002137774572474882 Validation error: 0.0001729822251945734
# Window 32 Neurons 21 optimizer nadam
# Timed stopping at epoch 37 after training for 0:00:05
# Training error: 0.0002871468022931367 Validation error: 0.0002718273608479649
# Window 25 Neurons 20 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00017903998377732933 Validation error: 0.00018144516798201948
# Window 33 Neurons 21 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.0002600029401946813 Validation error: 0.0006180168129503727
# Window 35 Neurons 21 optimizer adam
# Window 45 Neurons 21 optimizer adam
# Window 24 Neurons 20 optimizer nadam
# Window 24 Neurons 20 optimizer nadam
# Window 40 Neurons 21 optimizer nadam
# Timed stopping at epoch 38 after training for 0:00:05
# Training error: 0.00025999665376730263 Validation error: 0.0001975100749405101
# Window 32 Neurons 24 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00022535696916747838 Validation error: 0.00037715479265898466
# Window 46 Neurons 25 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00023744520149193704 Validation error: 0.0002198398142354563
# Window 40 Neurons 17 optimizer adam
# Window 24 Neurons 21 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00030188975506462157 Validation error: 0.00023461291857529432
# Window 35 Neurons 21 optimizer adam
# 11 	24
# Window 46 Neurons 16 optimizer adam
# Window 49 Neurons 26 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0001969027944141999 Validation error: 0.0002429403830319643
# Window 20 Neurons 20 optimizer nadam
# Window 53 Neurons 17 optimizer nadam
# Timed stopping at epoch 40 after training for 0:00:05
# Training error: 0.0004023037035949528 Validation error: 0.000436524860560894
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 48 Neurons 24 optimizer adam
# Window 48 Neurons 24 optimizer adam
# Window 42 Neurons 22 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.0002707494713831693 Validation error: 0.0002845056587830186
# Window 41 Neurons 23 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00023736550065223128 Validation error: 0.0004371397662907839
# Window 34 Neurons 21 optimizer adam
# Window 49 Neurons 17 optimizer adam
# Window 33 Neurons 21 optimizer adam
# Window 34 Neurons 21 optimizer adam
# Window 34 Neurons 21 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00031156360637396574 Validation error: 0.00021624969667755067
# Window 25 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 24 Neurons 20 optimizer nadam
# Window 41 Neurons 19 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00023943300766404718 Validation error: 0.00019944207451771945
# Window 32 Neurons 18 optimizer nadam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.00020211341325193644 Validation error: 0.00022721558343619108
# 12 	20
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 44 Neurons 18 optimizer adam
# Window 39 Neurons 20 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00017466448480263352 Validation error: 0.0001326309866271913
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 44 Neurons 20 optimizer adam
# Window 37 Neurons 16 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0002313150034751743 Validation error: 0.00017131170898210257
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 37 Neurons 20 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00018904580792877823 Validation error: 0.0001656034728512168
# Window 47 Neurons 17 optimizer adam
# Window 47 Neurons 19 optimizer adam
# Window 37 Neurons 18 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00026236395933665335 Validation error: 0.00020525908621493727
# Window 27 Neurons 21 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0002245054638478905 Validation error: 0.00016701880667824298
# Window 31 Neurons 20 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00023601930297445506 Validation error: 0.00024440421839244664
# Window 25 Neurons 20 optimizer nadam
# Timed stopping at epoch 41 after training for 0:00:05
# Training error: 0.00019162871467415243 Validation error: 0.00017314449360128492
# Window 24 Neurons 22 optimizer adam
# Window 32 Neurons 20 optimizer adam
# Window 26 Neurons 20 optimizer adam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.00019485843949951231 Validation error: 0.00015281497326213866
# 13 	20
# Window 24 Neurons 20 optimizer nadam
# Window 26 Neurons 20 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.00022152926248963922 Validation error: 0.00020275537099223584
# Window 25 Neurons 20 optimizer nadam
# Window 24 Neurons 20 optimizer nadam
# Window 38 Neurons 20 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00019609768060036004 Validation error: 0.00019267895550001413
# Window 35 Neurons 17 optimizer nadam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.0002649301604833454 Validation error: 0.0002452581247780472
# Window 33 Neurons 21 optimizer nadam
# Window 25 Neurons 20 optimizer adam
# Window 36 Neurons 20 optimizer adam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.0002045518485829234 Validation error: 0.00017205816402565688
# Window 36 Neurons 19 optimizer adam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.00020483866683207452 Validation error: 0.00017500946705695242
# Window 42 Neurons 19 optimizer adam
# Timed stopping at epoch 46 after training for 0:00:05
# Training error: 0.00023517635418102145 Validation error: 0.0003200939390808344
# Window 41 Neurons 18 optimizer adam
# Window 51 Neurons 21 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00021825682779308408 Validation error: 0.00017106483574025333
# Window 32 Neurons 16 optimizer adam
# Timed stopping at epoch 41 after training for 0:00:05
# Training error: 0.00023458898067474365 Validation error: 0.0001933503954205662
# Window 35 Neurons 21 optimizer adam
# Window 36 Neurons 20 optimizer adam
# 14 	16
# Window 31 Neurons 20 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0002816212363541126 Validation error: 0.00025374279357492924
# Window 30 Neurons 20 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.00022432203695643693 Validation error: 0.00018232174625154585
# Window 28 Neurons 20 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0002560522116255015 Validation error: 0.00017195320106111467
# Window 31 Neurons 21 optimizer nadam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 36 Neurons 19 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 44 Neurons 23 optimizer adam
# Timed stopping at epoch 42 after training for 0:00:05
# Training error: 0.00023946419241838157 Validation error: 0.00020309303363319486
# Window 39 Neurons 22 optimizer adam
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0002273019345011562 Validation error: 0.00019230657198932022
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 26 Neurons 20 optimizer nadam
# Window 33 Neurons 21 optimizer adam
# Window 24 Neurons 21 optimizer nadam
# Window 36 Neurons 20 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 17 optimizer adam
# Timed stopping at epoch 44 after training for 0:00:05
# Training error: 0.000224603500100784 Validation error: 0.0002732021966949105
# Window 31 Neurons 20 optimizer adam
# Window 23 Neurons 20 optimizer nadam
# Timed stopping at epoch 43 after training for 0:00:05
# Training error: 0.0002455096982885152 Validation error: 0.0001869870611699298
# Window 35 Neurons 21 optimizer adamax
# Timed stopping at epoch 45 after training for 0:00:05
# Training error: 0.0002989992790389806 Validation error: 0.00033525814069435
# 15 	25

# %% [markdown]
# #### Muestra las mejores soluciones
# #### Show the best solutions

# %%
best_individuals = tools.selBest(population, k=len(population))
# extraer los mejores fenotipos
# extract best fenotype
best_fenotype = extract_fenotype(best_individuals[0], p)
best_fenotype = (13, 21, "nadam")
for chromosome in best_individuals:
    fenotype = extract_fenotype(chromosome, p)
    print_fenotype(fenotype, p)
# Out:
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 35 Neurons 21 optimizer adam
# Window 48 Neurons 24 optimizer adam
# Window 51 Neurons 21 optimizer adam
# Window 28 Neurons 20 optimizer nadam
# Window 36 Neurons 20 optimizer adam
# Window 36 Neurons 19 optimizer adam
# Window 30 Neurons 20 optimizer adam
# Window 23 Neurons 20 optimizer nadam
# Window 39 Neurons 22 optimizer adam
# Window 26 Neurons 20 optimizer nadam
# Window 44 Neurons 23 optimizer adam
# Window 24 Neurons 21 optimizer nadam
# Window 31 Neurons 20 optimizer adam
# Window 31 Neurons 20 optimizer nadam
# Window 33 Neurons 21 optimizer adam
# Window 35 Neurons 17 optimizer adam
# Window 35 Neurons 21 optimizer adamax
# Window 31 Neurons 21 optimizer nadam

# %% [markdown]
# #### Entrenar y probar al mejor individuo
# #### Train the best individual and test it

# %%
# para entrenar con todos los datos se puede poner en val_split 0.0
# create a larger training dataset by setting val_split to 0.0
# p["val_split"] = 0.0
# extender el entrenamiento aumentando los epochs
# extend the training by increasing epochs
p["epochs"] = 2000
# aumentar el tiempo de entrenamiento
# increase training time
p["seconds"] = 199

set_fenotype(best_fenotype, p)
print_fenotype(best_fenotype, p)

# construir la RNA
# build the ANN
start = datetime.now()
ann, history = create_ann(p, train_scaled, train_scaled)
print("Runtime: {}".format(datetime.now()-start))

# desplegar los errores de entrenamiento y validación
# display training and validation losses
if (p["val_split"]==0.0):
    print("Training error: {}".
      format(history.history["loss"][-1]))
else:
    print("Training error: {} Validation error: {}".
      format(history.history["loss"][-1], history.history["val_loss"][-1]))
# Out:
# Window 13 Neurons 21 optimizer nadam
# Timed stopping at epoch 1268 after training for 0:03:19
# Runtime: 0:03:19.220629
# Training error: 0.00010644557187333703 Validation error: 0.00010392403783043846

# %% [markdown]
# ##### Despliegue gráfico del rendimiento de la RNA entrenada
# ##### Graphically display the performance of the trained ANN

# %%
X_train, y_train = prepare_time_series(
    train_scaled, train_scaled, p["Window"])
X_test, y_test = prepare_time_series(
    test_scaled, test_scaled, p["Window"])
ann_train_loss = ann.evaluate(x=X_train,
    y=y_train,
    batch_size=p["batch_size"])
ann_test_loss = ann.evaluate(x=X_test,
    y=y_test,
    batch_size=p["batch_size"])
y_train_pred = ann.predict(X_train)
y_test_pred = ann.predict(X_test)

print("ANN train: {}".format(ann_train_loss))
print("ANN test: {}".format(ann_test_loss))
print("MSE of a trivial predictor on train data:\t{:0.8f}".
        format(mean_squared_error(y_train[1:], y_train[:-1])))
print("MSE of a trivial predictor on test data:\t{:0.8f}".
        format(mean_squared_error(y_test[1:], y_test[:-1])))
print("MSE of the trained ANN on train data:\t{:0.8f}".
        format(mean_squared_error(y_train, y_train_pred)))
print("MSE of the trained ANN on test data:\t{:0.8f}".
        format(mean_squared_error(y_test, y_test_pred)))

plt.figure(figsize=(20, 12))
plt.subplot(1,2,1)
plt.plot(range(test_split), train_scaled, label="train")
plt.plot(range(test_split, len(df)), test_scaled, label="test")
plt.plot(range(p["Window"], p["Window"] + len(y_train_pred)),
            y_train_pred, label="trained")
plt.plot(range(p["Window"] + test_split, p["Window"] + test_split + len(y_test_pred)),
            y_test_pred, label="test prediction")
plt.title("Original data and ANN predictions")
plt.xlabel("Observation")
plt.ylabel("S&P500 Close Daily scaled")
plt.legend()

skip = 50  # si los primeros valores son muy altos se pueden eliminar
# del gráfico para evitar que afecten la escala automática
# avoid autoscale issues
plt.subplot(122)
plt.plot(history.history["loss"][skip:], "g",
            label="Training loss")
if (p["val_split"] != 0.0):
    plt.plot(history.history["val_loss"][skip:], "b",
                label="Validation loss")
plt.title("Loss evolution during training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# 129/129 [==============================] - 0s 1ms/step - loss: 1.0708e-04
# 32/32 [==============================] - 0s 1ms/step - loss: 2.6412e-04
# ANN train: 0.00010707681212807074
# ANN test: 0.00026412145234644413
# MSE of a trivial predictor on train data:	0.00010437
# MSE of a trivial predictor on test data:	0.00020313
# MSE of the trained ANN on train data:	0.00010708
# MSE of the trained ANN on test data:	0.00026412

# %% [markdown]
# ```
# # resultados variando el optimizador
# best_ann = (149, 18, 71)  # con 10% de mutación
# best_ann = (33, 14, 78)  # con 5% de mutación
# Test loss
# adamax   0.00017806104733608663 low sigma
# adam     0.0002559765998739749 medium sigma
# nadam    0.0002807788841892034 high sigma
# sgd      0.0015213494189083576 smooth
# rmsprop  0.002701616147533059 high sigma
# adagrad  0.010729542002081871 smooth
# ftrl     0.10698116570711136 bad
# adadelta 0.4015085995197296 bad
#
# best so far (13, 21, 30, nadam)
# ```
